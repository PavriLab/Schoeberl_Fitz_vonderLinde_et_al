# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
# pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC17mm9.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'mu+' 'ISCEgamma1+-5kb' '3CBE3RR' -r2 'mu+' 'ISCEgamma1+-5kb' '3CBE3RR' \
	--prefix 'TriC17_priB_B18AIDKO_d3' \
	--dir '../TriCplots/TriC17_mapq20' --capture 'Emu_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums = contactsums[::-1]
contactsums
# Out:
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                      sample replicate treatment_time          region1  \
# 53  TriC17_priB_B18AIDKO_d3         3         +3hTPL          3CBE3RR
# 52  TriC17_priB_B18AIDKO_d3         3         +3hTPL          3CBE3RR
# 51  TriC17_priB_B18AIDKO_d3         3         +3hTPL          3CBE3RR
# 50  TriC17_priB_B18AIDKO_d3         3         +3hTPL  ISCEgamma1+-5kb
# 49  TriC17_priB_B18AIDKO_d3         3         +3hTPL  ISCEgamma1+-5kb
# 48  TriC17_priB_B18AIDKO_d3         3         +3hTPL              mu+
# 47  TriC17_priB_B18AIDKO_d3         2         +1hTPL          3CBE3RR
# 46  TriC17_priB_B18AIDKO_d3         2         +1hTPL          3CBE3RR
# 45  TriC17_priB_B18AIDKO_d3         2         +1hTPL          3CBE3RR
# 44  TriC17_priB_B18AIDKO_d3         2         +1hTPL  ISCEgamma1+-5kb
# 43  TriC17_priB_B18AIDKO_d3         2         +1hTPL  ISCEgamma1+-5kb
# 42  TriC17_priB_B18AIDKO_d3         2         +1hTPL              mu+
# 41  TriC17_priB_B18AIDKO_d3         1           -TPL          3CBE3RR
# 40  TriC17_priB_B18AIDKO_d3         1           -TPL          3CBE3RR
# 39  TriC17_priB_B18AIDKO_d3         1           -TPL          3CBE3RR
# 38  TriC17_priB_B18AIDKO_d3         1           -TPL  ISCEgamma1+-5kb
# 37  TriC17_priB_B18AIDKO_d3         1           -TPL  ISCEgamma1+-5kb
# 36  TriC17_priB_B18AIDKO_d3         1           -TPL              mu+
# 35  TriC17_priB_B18AIDKO_d3         2         +3hTPL          3CBE3RR
# 34  TriC17_priB_B18AIDKO_d3         2         +3hTPL          3CBE3RR
# 33  TriC17_priB_B18AIDKO_d3         2         +3hTPL          3CBE3RR
# 32  TriC17_priB_B18AIDKO_d3         2         +3hTPL  ISCEgamma1+-5kb
# 31  TriC17_priB_B18AIDKO_d3         2         +3hTPL  ISCEgamma1+-5kb
# 30  TriC17_priB_B18AIDKO_d3         2         +3hTPL              mu+
# 29  TriC17_priB_B18AIDKO_d3         1         +1hTPL          3CBE3RR
# 28  TriC17_priB_B18AIDKO_d3         1         +1hTPL          3CBE3RR
# 27  TriC17_priB_B18AIDKO_d3         1         +1hTPL          3CBE3RR
# 26  TriC17_priB_B18AIDKO_d3         1         +1hTPL  ISCEgamma1+-5kb
# 25  TriC17_priB_B18AIDKO_d3         1         +1hTPL  ISCEgamma1+-5kb
# 24  TriC17_priB_B18AIDKO_d3         1         +1hTPL              mu+
# 23  TriC17_priB_B18AIDKO_d3         3           -TPL          3CBE3RR
# 22  TriC17_priB_B18AIDKO_d3         3           -TPL          3CBE3RR
# 21  TriC17_priB_B18AIDKO_d3         3           -TPL          3CBE3RR
# 20  TriC17_priB_B18AIDKO_d3         3           -TPL  ISCEgamma1+-5kb
# 19  TriC17_priB_B18AIDKO_d3         3           -TPL  ISCEgamma1+-5kb
# 18  TriC17_priB_B18AIDKO_d3         3           -TPL              mu+
# 17  TriC17_priB_B18AIDKO_d3         2           -TPL          3CBE3RR
# 16  TriC17_priB_B18AIDKO_d3         2           -TPL          3CBE3RR
# 15  TriC17_priB_B18AIDKO_d3         2           -TPL          3CBE3RR
# 14  TriC17_priB_B18AIDKO_d3         2           -TPL  ISCEgamma1+-5kb
# 13  TriC17_priB_B18AIDKO_d3         2           -TPL  ISCEgamma1+-5kb
# 12  TriC17_priB_B18AIDKO_d3         2           -TPL              mu+
# 11  TriC17_priB_B18AIDKO_d3         1         +3hTPL          3CBE3RR
# 10  TriC17_priB_B18AIDKO_d3         1         +3hTPL          3CBE3RR
# 9   TriC17_priB_B18AIDKO_d3         1         +3hTPL          3CBE3RR
# 8   TriC17_priB_B18AIDKO_d3         1         +3hTPL  ISCEgamma1+-5kb
# 7   TriC17_priB_B18AIDKO_d3         1         +3hTPL  ISCEgamma1+-5kb
# 6   TriC17_priB_B18AIDKO_d3         1         +3hTPL              mu+
# 5   TriC17_priB_B18AIDKO_d3         3         +1hTPL          3CBE3RR
# 4   TriC17_priB_B18AIDKO_d3         3         +1hTPL          3CBE3RR
# 3   TriC17_priB_B18AIDKO_d3         3         +1hTPL          3CBE3RR
# 2   TriC17_priB_B18AIDKO_d3         3         +1hTPL  ISCEgamma1+-5kb
# 1   TriC17_priB_B18AIDKO_d3         3         +1hTPL  ISCEgamma1+-5kb
# 0   TriC17_priB_B18AIDKO_d3         3         +1hTPL              mu+
#
#             region2  pinteractions                         regioncomb
# 53          3CBE3RR      39.471078                  3CBE3RR - 3CBE3RR
# 52  ISCEgamma1+-5kb       9.405916          3CBE3RR - ISCEgamma1+-5kb
# 51              mu+      13.030726                      3CBE3RR - mu+
# 50  ISCEgamma1+-5kb      41.956071  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 49              mu+      18.323571              ISCEgamma1+-5kb - mu+
# 48              mu+     320.500208                          mu+ - mu+
# 47          3CBE3RR      37.384977                  3CBE3RR - 3CBE3RR
# 46  ISCEgamma1+-5kb       9.484771          3CBE3RR - ISCEgamma1+-5kb
# 45              mu+      12.566624                      3CBE3RR - mu+
# 44  ISCEgamma1+-5kb      41.513520  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 43              mu+      32.684107              ISCEgamma1+-5kb - mu+
# 42              mu+     275.849444                          mu+ - mu+
# 41          3CBE3RR      28.020598                  3CBE3RR - 3CBE3RR
# 40  ISCEgamma1+-5kb       5.993654          3CBE3RR - ISCEgamma1+-5kb
# 39              mu+      10.368355                      3CBE3RR - mu+
# 38  ISCEgamma1+-5kb      45.565051  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 37              mu+       4.991518              ISCEgamma1+-5kb - mu+
# 36              mu+     385.419514                          mu+ - mu+
# 35          3CBE3RR      44.956995                  3CBE3RR - 3CBE3RR
# 34  ISCEgamma1+-5kb       8.679899          3CBE3RR - ISCEgamma1+-5kb
# 33              mu+      13.790748                      3CBE3RR - mu+
# 32  ISCEgamma1+-5kb      47.413291  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 31              mu+      35.613095              ISCEgamma1+-5kb - mu+
# 30              mu+     242.701528                          mu+ - mu+
# 29          3CBE3RR      44.925930                  3CBE3RR - 3CBE3RR
# 28  ISCEgamma1+-5kb       8.775385          3CBE3RR - ISCEgamma1+-5kb
# 27              mu+       8.964829                      3CBE3RR - mu+
# 26  ISCEgamma1+-5kb      63.757117  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 25              mu+      19.582321              ISCEgamma1+-5kb - mu+
# 24              mu+     257.491319                          mu+ - mu+
# 23          3CBE3RR      29.503149                  3CBE3RR - 3CBE3RR
# 22  ISCEgamma1+-5kb       7.563663          3CBE3RR - ISCEgamma1+-5kb
# 21              mu+       9.160406                      3CBE3RR - mu+
# 20  ISCEgamma1+-5kb      34.556416  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 19              mu+       4.134464              ISCEgamma1+-5kb - mu+
# 18              mu+     440.856250                          mu+ - mu+
# 17          3CBE3RR      33.767844                  3CBE3RR - 3CBE3RR
# 16  ISCEgamma1+-5kb       4.668315          3CBE3RR - ISCEgamma1+-5kb
# 15              mu+      12.596132                      3CBE3RR - mu+
# 14  ISCEgamma1+-5kb      31.848788  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 13              mu+      13.143095              ISCEgamma1+-5kb - mu+
# 12              mu+     343.869514                          mu+ - mu+
# 11          3CBE3RR      46.323544                  3CBE3RR - 3CBE3RR
# 10  ISCEgamma1+-5kb       9.604121          3CBE3RR - ISCEgamma1+-5kb
# 9               mu+      16.068269                      3CBE3RR - mu+
# 8   ISCEgamma1+-5kb      45.116301  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 7               mu+      15.951964              ISCEgamma1+-5kb - mu+
# 6               mu+     318.088750                          mu+ - mu+
# 5           3CBE3RR      50.141801                  3CBE3RR - 3CBE3RR
# 4   ISCEgamma1+-5kb      12.185311          3CBE3RR - ISCEgamma1+-5kb
# 3               mu+      17.733547                      3CBE3RR - mu+
# 2   ISCEgamma1+-5kb      60.392844  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 1               mu+      20.838363              ISCEgamma1+-5kb - mu+
# 0               mu+     242.641667                          mu+ - mu+

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'purple', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1])), ((reg, contactsums['treatment_time'].unique()[1]), (reg, contactsums['treatment_time'].unique()[2])), ((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[2]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', 
		box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2, line_offset=0.3, line_offset_to_box=0.2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'Emu_capture -- {region1} -- x')
fig.suptitle('TriC17_mm9AIDKO-TPL Emu interactions')

fig.savefig('../plots/TriC17/TriC17_mm9AIDKO-TPL_RegOfInterest_EmuCap_allZones.pdf')
# Out:
# ISCEgamma1+-5kb_+1hTPL v.s. ISCEgamma1+-5kb_-TPL: t-test independent samples with Bonferroni correction, P_val=3.410e-01 stat=3.054e+00
# mu+_+3hTPL v.s. mu+_+1hTPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=4.469e-01
# mu+_+1hTPL v.s. mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=8.698e-01
# 3CBE3RR_+3hTPL v.s. 3CBE3RR_+1hTPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.333e-01
# 3CBE3RR_+1hTPL v.s. 3CBE3RR_-TPL: t-test independent samples with Bonferroni correction, P_val=2.549e-01 stat=3.360e+00
# ISCEgamma1+-5kb_+3hTPL v.s. ISCEgamma1+-5kb_+1hTPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-8.535e-01
# mu+_+3hTPL v.s. mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=5.175e-01 stat=2.641e+00
# ISCEgamma1+-5kb_+3hTPL v.s. ISCEgamma1+-5kb_-TPL: t-test independent samples with Bonferroni correction, P_val=2.096e-01 stat=3.574e+00
# 3CBE3RR_+3hTPL v.s. 3CBE3RR_-TPL: t-test independent samples with Bonferroni correction, P_val=7.500e-02 stat=4.851e+00
# mu+_+1hTPL v.s. mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=1.722e-01 stat=3.345e+00
# ISCEgamma1+-5kb_+3hTPL v.s. ISCEgamma1+-5kb_+1hTPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.464e+00
# ISCEgamma1+-5kb_+1hTPL v.s. ISCEgamma1+-5kb_-TPL: t-test independent samples with Bonferroni correction, P_val=5.490e-01 stat=2.211e+00
# mu+_+3hTPL v.s. mu+_+1hTPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.435e-01
# mu+_+3hTPL v.s. mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=4.845e-01 stat=2.324e+00
# ISCEgamma1+-5kb_+3hTPL v.s. ISCEgamma1+-5kb_-TPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.674e+00
# mu+_+3hTPL v.s. mu+_+1hTPL: t-test independent samples with Bonferroni correction, P_val=8.031e-01 stat=1.286e+00
# mu+_+1hTPL v.s. mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=3.439e-02 stat=-4.425e+00
# mu+_+3hTPL v.s. mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=1.928e-01 stat=-2.536e+00

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

contactsums = contactsums.drop(contactsums[contactsums.treatment_time == '+1hTPL'].index)

region_order = ['mu+ - mu+', 'ISCEgamma1+-5kb - mu+', '3CBE3RR - mu+', 'ISCEgamma1+-5kb - ISCEgamma1+-5kb', '3CBE3RR - ISCEgamma1+-5kb', '3CBE3RR - 3CBE3RR']

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5

# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
ax = fig.add_subplot(111, yscale = 'log')
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, order=region_order, ax=ax, bottom=0.001)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	order=region_order, palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2)

handles, labels = ax.get_legend_handles_labels()
# ax.legend_.remove()
# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
ax.set_ylabel('log(Interactions norm. by N of bins)')
ax.set_xlabel("x regions")
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
ax.set_title(f'Emu_capture -- x')
ax.set_ylim(3)
fig.suptitle('TriC17_mm9AIDKO-TPL Emu interactions')

fig.savefig('../plots/TriC17/TriC17_mm9AIDKO-TPL_RegOfInterest_EmuCap_allZones_combined.pdf')
# Out:
# ISCEgamma1+-5kb - mu+_+3hTPL v.s. ISCEgamma1+-5kb - mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=4.845e-01 stat=2.324e+00
# mu+ - mu+_+3hTPL v.s. mu+ - mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=3.855e-01 stat=-2.536e+00
# 3CBE3RR - mu+_+3hTPL v.s. 3CBE3RR - mu+_-TPL: t-test independent samples with Bonferroni correction, P_val=3.450e-01 stat=2.641e+00
# 3CBE3RR - 3CBE3RR_+3hTPL v.s. 3CBE3RR - 3CBE3RR_-TPL: t-test independent samples with Bonferroni correction, P_val=5.000e-02 stat=4.851e+00
# 3CBE3RR - ISCEgamma1+-5kb_+3hTPL v.s. 3CBE3RR - ISCEgamma1+-5kb_-TPL: t-test independent samples with Bonferroni correction, P_val=1.398e-01 stat=3.574e+00
# ISCEgamma1+-5kb - ISCEgamma1+-5kb_+3hTPL v.s. ISCEgamma1+-5kb - ISCEgamma1+-5kb_-TPL: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.674e+00
