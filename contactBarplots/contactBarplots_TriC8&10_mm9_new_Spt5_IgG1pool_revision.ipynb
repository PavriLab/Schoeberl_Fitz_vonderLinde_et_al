# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
# pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_10.tsv' '../resource/sampleinfo_TriC_8_noVDJnoSort_rerun.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'mu+' 'ISCEgamma1+-5kb' '3CBE3RR' -r2 'mu+' 'ISCEgamma1+-5kb' '3CBE3RR' \
	--prefix 'TriC_10_lane_1_Spt5' 'TriC8_lane_2_Spt5' \
	--dir '../TriCplots/TriC10_mapq20_TriC8_mapq20_rerun' --capture 'IgG1_pool_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums
# Out:
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                    sample replicate treatment_time          region1  \
# 0   TriC_10_lane_1_Spt5_2         1             KO              mu+
# 1   TriC_10_lane_1_Spt5_2         1             KO  ISCEgamma1+-5kb
# 2   TriC_10_lane_1_Spt5_2         1             KO  ISCEgamma1+-5kb
# 3   TriC_10_lane_1_Spt5_2         1             KO          3CBE3RR
# 4   TriC_10_lane_1_Spt5_2         1             KO          3CBE3RR
# 5   TriC_10_lane_1_Spt5_2         1             KO          3CBE3RR
# 6   TriC_10_lane_1_Spt5_2         2             KO              mu+
# 7   TriC_10_lane_1_Spt5_2         2             KO  ISCEgamma1+-5kb
# 8   TriC_10_lane_1_Spt5_2         2             KO  ISCEgamma1+-5kb
# 9   TriC_10_lane_1_Spt5_2         2             KO          3CBE3RR
# 10  TriC_10_lane_1_Spt5_2         2             KO          3CBE3RR
# 11  TriC_10_lane_1_Spt5_2         2             KO          3CBE3RR
# 12  TriC_10_lane_1_Spt5_2         3             KO              mu+
# 13  TriC_10_lane_1_Spt5_2         3             KO  ISCEgamma1+-5kb
# 14  TriC_10_lane_1_Spt5_2         3             KO  ISCEgamma1+-5kb
# 15  TriC_10_lane_1_Spt5_2         3             KO          3CBE3RR
# 16  TriC_10_lane_1_Spt5_2         3             KO          3CBE3RR
# 17  TriC_10_lane_1_Spt5_2         3             KO          3CBE3RR
# 18  TriC_10_lane_1_Spt5_2         1           ctrl              mu+
# 19  TriC_10_lane_1_Spt5_2         1           ctrl  ISCEgamma1+-5kb
# 20  TriC_10_lane_1_Spt5_2         1           ctrl  ISCEgamma1+-5kb
# 21  TriC_10_lane_1_Spt5_2         1           ctrl          3CBE3RR
# 22  TriC_10_lane_1_Spt5_2         1           ctrl          3CBE3RR
# 23  TriC_10_lane_1_Spt5_2         1           ctrl          3CBE3RR
# 24  TriC_10_lane_1_Spt5_2         2           ctrl              mu+
# 25  TriC_10_lane_1_Spt5_2         2           ctrl  ISCEgamma1+-5kb
# 26  TriC_10_lane_1_Spt5_2         2           ctrl  ISCEgamma1+-5kb
# 27  TriC_10_lane_1_Spt5_2         2           ctrl          3CBE3RR
# 28  TriC_10_lane_1_Spt5_2         2           ctrl          3CBE3RR
# 29  TriC_10_lane_1_Spt5_2         2           ctrl          3CBE3RR
# 30      TriC8_lane_2_Spt5         3             KO              mu+
# 31      TriC8_lane_2_Spt5         3             KO  ISCEgamma1+-5kb
# 32      TriC8_lane_2_Spt5         3             KO  ISCEgamma1+-5kb
# 33      TriC8_lane_2_Spt5         3             KO          3CBE3RR
# 34      TriC8_lane_2_Spt5         3             KO          3CBE3RR
# 35      TriC8_lane_2_Spt5         3             KO          3CBE3RR
# 36      TriC8_lane_2_Spt5         4             KO              mu+
# 37      TriC8_lane_2_Spt5         4             KO  ISCEgamma1+-5kb
# 38      TriC8_lane_2_Spt5         4             KO  ISCEgamma1+-5kb
# 39      TriC8_lane_2_Spt5         4             KO          3CBE3RR
# 40      TriC8_lane_2_Spt5         4             KO          3CBE3RR
# 41      TriC8_lane_2_Spt5         4             KO          3CBE3RR
# 42      TriC8_lane_2_Spt5         1           ctrl              mu+
# 43      TriC8_lane_2_Spt5         1           ctrl  ISCEgamma1+-5kb
# 44      TriC8_lane_2_Spt5         1           ctrl  ISCEgamma1+-5kb
# 45      TriC8_lane_2_Spt5         1           ctrl          3CBE3RR
# 46      TriC8_lane_2_Spt5         1           ctrl          3CBE3RR
# 47      TriC8_lane_2_Spt5         1           ctrl          3CBE3RR
# 48      TriC8_lane_2_Spt5         3           ctrl              mu+
# 49      TriC8_lane_2_Spt5         3           ctrl  ISCEgamma1+-5kb
# 50      TriC8_lane_2_Spt5         3           ctrl  ISCEgamma1+-5kb
# 51      TriC8_lane_2_Spt5         3           ctrl          3CBE3RR
# 52      TriC8_lane_2_Spt5         3           ctrl          3CBE3RR
# 53      TriC8_lane_2_Spt5         3           ctrl          3CBE3RR
#
#             region2  pinteractions                         regioncomb
# 0               mu+      64.922431                          mu+ - mu+
# 1               mu+       5.654018              ISCEgamma1+-5kb - mu+
# 2   ISCEgamma1+-5kb     115.001645  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 3               mu+       2.501774                      3CBE3RR - mu+
# 4   ISCEgamma1+-5kb       5.047271          3CBE3RR - ISCEgamma1+-5kb
# 5           3CBE3RR      14.008402                  3CBE3RR - 3CBE3RR
# 6               mu+      52.962361                          mu+ - mu+
# 7               mu+       5.917262              ISCEgamma1+-5kb - mu+
# 8   ISCEgamma1+-5kb     108.913954  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 9               mu+       2.798034                      3CBE3RR - mu+
# 10  ISCEgamma1+-5kb       4.727106          3CBE3RR - ISCEgamma1+-5kb
# 11          3CBE3RR      12.174569                  3CBE3RR - 3CBE3RR
# 12              mu+      47.256458                          mu+ - mu+
# 13              mu+       5.614345              ISCEgamma1+-5kb - mu+
# 14  ISCEgamma1+-5kb     115.807526  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 15              mu+       2.416026                      3CBE3RR - mu+
# 16  ISCEgamma1+-5kb       3.908251          3CBE3RR - ISCEgamma1+-5kb
# 17          3CBE3RR      12.655569                  3CBE3RR - 3CBE3RR
# 18              mu+     164.996806                          mu+ - mu+
# 19              mu+       5.662351              ISCEgamma1+-5kb - mu+
# 20  ISCEgamma1+-5kb     109.867755  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 21              mu+       2.685171                      3CBE3RR - mu+
# 22  ISCEgamma1+-5kb       3.687885          3CBE3RR - ISCEgamma1+-5kb
# 23          3CBE3RR      19.822176                  3CBE3RR - 3CBE3RR
# 24              mu+     184.069167                          mu+ - mu+
# 25              mu+       3.061012              ISCEgamma1+-5kb - mu+
# 26  ISCEgamma1+-5kb     115.701773  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 27              mu+       1.352521                      3CBE3RR - mu+
# 28  ISCEgamma1+-5kb       3.185092          3CBE3RR - ISCEgamma1+-5kb
# 29          3CBE3RR      17.808350                  3CBE3RR - 3CBE3RR
# 30              mu+      87.148264                          mu+ - mu+
# 31              mu+       3.760030              ISCEgamma1+-5kb - mu+
# 32  ISCEgamma1+-5kb     115.127730  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 33              mu+       1.946517                      3CBE3RR - mu+
# 34  ISCEgamma1+-5kb       3.600769          3CBE3RR - ISCEgamma1+-5kb
# 35          3CBE3RR      20.957055                  3CBE3RR - 3CBE3RR
# 36              mu+      73.032083                          mu+ - mu+
# 37              mu+       6.290000              ISCEgamma1+-5kb - mu+
# 38  ISCEgamma1+-5kb     112.199133  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 39              mu+       3.021880                      3CBE3RR - mu+
# 40  ISCEgamma1+-5kb       4.008434          3CBE3RR - ISCEgamma1+-5kb
# 41          3CBE3RR      18.516989                  3CBE3RR - 3CBE3RR
# 42              mu+     204.583264                          mu+ - mu+
# 43              mu+       8.307857              ISCEgamma1+-5kb - mu+
# 44  ISCEgamma1+-5kb     101.336276  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 45              mu+       5.925940                      3CBE3RR - mu+
# 46  ISCEgamma1+-5kb       4.531383          3CBE3RR - ISCEgamma1+-5kb
# 47          3CBE3RR      22.754458                  3CBE3RR - 3CBE3RR
# 48              mu+     115.029514                          mu+ - mu+
# 49              mu+       5.579762              ISCEgamma1+-5kb - mu+
# 50  ISCEgamma1+-5kb     110.973342  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 51              mu+       2.632073                      3CBE3RR - mu+
# 52  ISCEgamma1+-5kb       5.379853          3CBE3RR - ISCEgamma1+-5kb
# 53          3CBE3RR      19.198508                  3CBE3RR - 3CBE3RR

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'IgG1_pool_capture -- {region1} -- x')
fig.suptitle('TriC8&10_mm9Spt5 interactions')

fig.savefig('../plots/TriC10/TriC8&10_mm9Spt5_RegOfInterest_IgG1poolCap_allZones.pdf')
# Out:
# ISCEgamma1+-5kb_KO v.s. ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.192e-01
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-6.943e-01
# 3CBE3RR_KO v.s. 3CBE3RR_ctrl: t-test independent samples with Bonferroni correction, P_val=2.756e-01 stat=-1.952e+00
# ISCEgamma1+-5kb_KO v.s. ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=4.619e-01 stat=1.312e+00
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.932e-01
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=9.375e-04 stat=-5.468e+00

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

region_order = ['mu+ - mu+', 'ISCEgamma1+-5kb - mu+', '3CBE3RR - mu+', 'ISCEgamma1+-5kb - ISCEgamma1+-5kb', '3CBE3RR - ISCEgamma1+-5kb', '3CBE3RR - 3CBE3RR']

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5

# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
ax = fig.add_subplot(111, yscale = 'log')
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, order=region_order, ax=ax, bottom=0.001)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	order=region_order, palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2)

handles, labels = ax.get_legend_handles_labels()
# ax.legend_.remove()
# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
ax.set_ylabel('log(Interactions norm. by N of bins)')
ax.set_xlabel("x regions")
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
ax.set_title(f'IgG1_pool_capture -- x')
fig.suptitle('TriC8&10_mm9Spt5 interactions')
ax.set_ylim(1)
fig.savefig('../plots/TriC10/TriC8&10_mm9Spt5_RegOfInterest_IgG1poolCap_allZones_combined.pdf')
# Out:
# ISCEgamma1+-5kb - mu+_KO v.s. ISCEgamma1+-5kb - mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.932e-01
# mu+ - mu+_KO v.s. mu+ - mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=5.625e-03 stat=-5.468e+00
# 3CBE3RR - mu+_KO v.s. 3CBE3RR - mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-6.943e-01
# ISCEgamma1+-5kb - ISCEgamma1+-5kb_KO v.s. ISCEgamma1+-5kb - ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.312e+00
# 3CBE3RR - ISCEgamma1+-5kb_KO v.s. 3CBE3RR - ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.192e-01
# 3CBE3RR - 3CBE3RR_KO v.s. 3CBE3RR - 3CBE3RR_ctrl: t-test independent samples with Bonferroni correction, P_val=5.512e-01 stat=-1.952e+00

# %%
boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
boxlist
# Out:
# [(('mu+ - mu+', 'KO'), ('mu+ - mu+', 'ctrl')),
#  (('ISCEgamma1+-5kb - mu+', 'KO'), ('ISCEgamma1+-5kb - mu+', 'ctrl')),
#  (('ISCEgamma1+-5kb - ISCEgamma1+-5kb', 'KO'),
#   ('ISCEgamma1+-5kb - ISCEgamma1+-5kb', 'ctrl')),
#  (('3CBE3RR - mu+', 'KO'), ('3CBE3RR - mu+', 'ctrl')),
#  (('3CBE3RR - ISCEgamma1+-5kb', 'KO'), ('3CBE3RR - ISCEgamma1+-5kb', 'ctrl')),
#  (('3CBE3RR - 3CBE3RR', 'KO'), ('3CBE3RR - 3CBE3RR', 'ctrl'))]
