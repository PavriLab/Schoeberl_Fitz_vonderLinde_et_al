# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
# pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_11.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'mu+' 'ISCEgamma1+-5kb' '3CBE3RR' -r2 'mu+' 'ISCEgamma1+-5kb' '3CBE3RR' \
	--prefix 'TriC_11_lane_1_Spt5_2' \
	--dir '../TriCplots/TriC11_mapq20' --capture 'IgG2a_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums = contactsums[::-1]
contactsums
# Out:
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                    sample replicate treatment_time          region1  \
# 29  TriC_11_lane_1_Spt5_2         3             KO          3CBE3RR
# 28  TriC_11_lane_1_Spt5_2         3             KO          3CBE3RR
# 27  TriC_11_lane_1_Spt5_2         3             KO          3CBE3RR
# 26  TriC_11_lane_1_Spt5_2         3             KO  ISCEgamma1+-5kb
# 25  TriC_11_lane_1_Spt5_2         3             KO  ISCEgamma1+-5kb
# 24  TriC_11_lane_1_Spt5_2         3             KO              mu+
# 23  TriC_11_lane_1_Spt5_2         2             KO          3CBE3RR
# 22  TriC_11_lane_1_Spt5_2         2             KO          3CBE3RR
# 21  TriC_11_lane_1_Spt5_2         2             KO          3CBE3RR
# 20  TriC_11_lane_1_Spt5_2         2             KO  ISCEgamma1+-5kb
# 19  TriC_11_lane_1_Spt5_2         2             KO  ISCEgamma1+-5kb
# 18  TriC_11_lane_1_Spt5_2         2             KO              mu+
# 17  TriC_11_lane_1_Spt5_2         1             KO          3CBE3RR
# 16  TriC_11_lane_1_Spt5_2         1             KO          3CBE3RR
# 15  TriC_11_lane_1_Spt5_2         1             KO          3CBE3RR
# 14  TriC_11_lane_1_Spt5_2         1             KO  ISCEgamma1+-5kb
# 13  TriC_11_lane_1_Spt5_2         1             KO  ISCEgamma1+-5kb
# 12  TriC_11_lane_1_Spt5_2         1             KO              mu+
# 11  TriC_11_lane_1_Spt5_2         2           ctrl          3CBE3RR
# 10  TriC_11_lane_1_Spt5_2         2           ctrl          3CBE3RR
# 9   TriC_11_lane_1_Spt5_2         2           ctrl          3CBE3RR
# 8   TriC_11_lane_1_Spt5_2         2           ctrl  ISCEgamma1+-5kb
# 7   TriC_11_lane_1_Spt5_2         2           ctrl  ISCEgamma1+-5kb
# 6   TriC_11_lane_1_Spt5_2         2           ctrl              mu+
# 5   TriC_11_lane_1_Spt5_2         1           ctrl          3CBE3RR
# 4   TriC_11_lane_1_Spt5_2         1           ctrl          3CBE3RR
# 3   TriC_11_lane_1_Spt5_2         1           ctrl          3CBE3RR
# 2   TriC_11_lane_1_Spt5_2         1           ctrl  ISCEgamma1+-5kb
# 1   TriC_11_lane_1_Spt5_2         1           ctrl  ISCEgamma1+-5kb
# 0   TriC_11_lane_1_Spt5_2         1           ctrl              mu+
#
#             region2  pinteractions                         regioncomb
# 29          3CBE3RR      11.590217                  3CBE3RR - 3CBE3RR
# 28  ISCEgamma1+-5kb       1.358919          3CBE3RR - ISCEgamma1+-5kb
# 27              mu+       0.979274                      3CBE3RR - mu+
# 26  ISCEgamma1+-5kb      25.891620  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 25              mu+       0.318810              ISCEgamma1+-5kb - mu+
# 24              mu+      15.004306                          mu+ - mu+
# 23          3CBE3RR      10.906101                  3CBE3RR - 3CBE3RR
# 22  ISCEgamma1+-5kb       0.996612          3CBE3RR - ISCEgamma1+-5kb
# 21              mu+       1.043889                      3CBE3RR - mu+
# 20  ISCEgamma1+-5kb      25.777564  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 19              mu+       0.179048              ISCEgamma1+-5kb - mu+
# 18              mu+      26.173264                          mu+ - mu+
# 17          3CBE3RR       9.716607                  3CBE3RR - 3CBE3RR
# 16  ISCEgamma1+-5kb       0.985183          3CBE3RR - ISCEgamma1+-5kb
# 15              mu+       1.065855                      3CBE3RR - mu+
# 14  ISCEgamma1+-5kb      24.695281  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 13              mu+       0.131310              ISCEgamma1+-5kb - mu+
# 12              mu+      20.680486                          mu+ - mu+
# 11          3CBE3RR      10.356805                  3CBE3RR - 3CBE3RR
# 10  ISCEgamma1+-5kb       0.347024          3CBE3RR - ISCEgamma1+-5kb
# 9               mu+       0.280705                      3CBE3RR - mu+
# 8   ISCEgamma1+-5kb      26.994936  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 7               mu+       0.595804              ISCEgamma1+-5kb - mu+
# 6               mu+      33.578681                          mu+ - mu+
# 5           3CBE3RR      13.056844                  3CBE3RR - 3CBE3RR
# 4   ISCEgamma1+-5kb       0.393892          3CBE3RR - ISCEgamma1+-5kb
# 3               mu+       0.964615                      3CBE3RR - mu+
# 2   ISCEgamma1+-5kb      22.938890  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 1               mu+       0.758452              ISCEgamma1+-5kb - mu+
# 0               mu+      32.802431                          mu+ - mu+

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', 
		box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2, line_offset=0.3, line_offset_to_box=0.2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'IgG2a_capture -- {region1} -- x')
fig.suptitle('TriC11_mm9Spt5 IgG2a interactions')

fig.savefig('../plots/TriC11/TriC11_mm9Spt5_RegOfInterest_IgG2aCap_allZones.pdf')
# Out:
# ISCEgamma1+-5kb_KO v.s. ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=5.587e-02 stat=4.662e+00
# 3CBE3RR_KO v.s. 3CBE3RR_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-7.882e-01
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=6.346e-01 stat=1.583e+00
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=3.180e-02 stat=-4.941e+00
# ISCEgamma1+-5kb_KO v.s. ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=3.069e-01
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=5.709e-02 stat=-3.013e+00

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

region_order = ['mu+ - mu+', 'ISCEgamma1+-5kb - mu+', '3CBE3RR - mu+', 'ISCEgamma1+-5kb - ISCEgamma1+-5kb', '3CBE3RR - ISCEgamma1+-5kb', '3CBE3RR - 3CBE3RR']

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5

# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
ax = fig.add_subplot(111, yscale = 'log')
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, order=region_order, ax=ax, bottom=0.001)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	order=region_order, palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2)

handles, labels = ax.get_legend_handles_labels()
# ax.legend_.remove()
# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
ax.set_ylabel('log(Interactions norm. by N of bins)')
ax.set_xlabel("x regions")
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
ax.set_title(f'IgG2a_capture -- x')
fig.suptitle('TriC11_mm9Spt5 IgG2a interactions')
ax.set_ylim(0.1)

fig.savefig('../plots/TriC11/TriC11_mm9Spt5_RegOfInterest_IgG2aCap_allZones_combined.pdf')
# Out:
# ISCEgamma1+-5kb - mu+_KO v.s. ISCEgamma1+-5kb - mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=9.541e-02 stat=-4.941e+00
# mu+ - mu+_KO v.s. mu+ - mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=3.425e-01 stat=-3.013e+00
# 3CBE3RR - mu+_KO v.s. 3CBE3RR - mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.583e+00
# 3CBE3RR - 3CBE3RR_KO v.s. 3CBE3RR - 3CBE3RR_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-7.882e-01
# 3CBE3RR - ISCEgamma1+-5kb_KO v.s. 3CBE3RR - ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.117e-01 stat=4.662e+00
# ISCEgamma1+-5kb - ISCEgamma1+-5kb_KO v.s. ISCEgamma1+-5kb - ISCEgamma1+-5kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=3.069e-01

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_11.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'CG2b-5prhs3a' -r2 'CG2b-5prhs3a' \
	--prefix 'TriC_11_lane_1_Spt5_2' \
	--dir '../TriCplots/TriC11_mapq20' --capture 'IgG2a_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums
# Out:
#                   sample replicate treatment_time       region1       region2  \
# 0  TriC_11_lane_1_Spt5_2         1           ctrl  CG2b-5prhs3a  CG2b-5prhs3a
# 1  TriC_11_lane_1_Spt5_2         2           ctrl  CG2b-5prhs3a  CG2b-5prhs3a
# 2  TriC_11_lane_1_Spt5_2         1             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 3  TriC_11_lane_1_Spt5_2         2             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 4  TriC_11_lane_1_Spt5_2         3             KO  CG2b-5prhs3a  CG2b-5prhs3a
#
#    pinteractions                   regioncomb
# 0      75.329768  CG2b-5prhs3a - CG2b-5prhs3a
# 1      74.678848  CG2b-5prhs3a - CG2b-5prhs3a
# 2      66.524192  CG2b-5prhs3a - CG2b-5prhs3a
# 3      67.350984  CG2b-5prhs3a - CG2b-5prhs3a
# 4      66.438572  CG2b-5prhs3a - CG2b-5prhs3a

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(10,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5

# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
ax = fig.add_subplot(111)
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2)

handles, labels = ax.get_legend_handles_labels()
# ax.legend_.remove()
# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
ax.set_ylabel('log(Interactions norm. by N of bins)')
ax.set_xlabel("x regions")
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
ax.set_title(f'IgG2a_capture -- x')
fig.suptitle('TriC11_mm9Spt5 IgG2a interactions')

fig.savefig('../plots/TriC11/TriC11_mm9Spt5_RegOfInterest_IgG2aCap_lowerTri.pdf')
# Out:
# CG2b-5prhs3a - CG2b-5prhs3a_ctrl v.s. CG2b-5prhs3a - CG2b-5prhs3a_KO: t-test independent samples with Bonferroni correction, P_val=3.495e-04 stat=1.841e+01
