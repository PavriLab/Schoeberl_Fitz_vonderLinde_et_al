# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
# pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_10.tsv' '../resource/sampleinfo_TriC_8_noVDJnoSort_rerun.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'hs3a-3b' '3CBEhs4' -r2 'mu+' 'noise2' 'IgG2a+-3kb' \
	--prefix 'TriC_10_lane_1_Spt5' 'TriC8_lane_2_Spt5' \
	--dir '../TriCplots/TriC10_mapq20_TriC8_mapq20_rerun' --capture 'IgG1_pool_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums
# Out:
#                    sample replicate treatment_time  region1     region2  \
# 0   TriC_10_lane_1_Spt5_2         1             KO  hs3a-3b         mu+
# 1   TriC_10_lane_1_Spt5_2         1             KO  hs3a-3b      noise2
# 2   TriC_10_lane_1_Spt5_2         1             KO  hs3a-3b  IgG2a+-3kb
# 3   TriC_10_lane_1_Spt5_2         1             KO  3CBEhs4         mu+
# 4   TriC_10_lane_1_Spt5_2         1             KO  3CBEhs4      noise2
# 5   TriC_10_lane_1_Spt5_2         1             KO  3CBEhs4  IgG2a+-3kb
# 6   TriC_10_lane_1_Spt5_2         2             KO  hs3a-3b         mu+
# 7   TriC_10_lane_1_Spt5_2         2             KO  hs3a-3b      noise2
# 8   TriC_10_lane_1_Spt5_2         2             KO  hs3a-3b  IgG2a+-3kb
# 9   TriC_10_lane_1_Spt5_2         2             KO  3CBEhs4         mu+
# 10  TriC_10_lane_1_Spt5_2         2             KO  3CBEhs4      noise2
# 11  TriC_10_lane_1_Spt5_2         2             KO  3CBEhs4  IgG2a+-3kb
# 12  TriC_10_lane_1_Spt5_2         3             KO  hs3a-3b         mu+
# 13  TriC_10_lane_1_Spt5_2         3             KO  hs3a-3b      noise2
# 14  TriC_10_lane_1_Spt5_2         3             KO  hs3a-3b  IgG2a+-3kb
# 15  TriC_10_lane_1_Spt5_2         3             KO  3CBEhs4         mu+
# 16  TriC_10_lane_1_Spt5_2         3             KO  3CBEhs4      noise2
# 17  TriC_10_lane_1_Spt5_2         3             KO  3CBEhs4  IgG2a+-3kb
# 18  TriC_10_lane_1_Spt5_2         1           ctrl  hs3a-3b         mu+
# 19  TriC_10_lane_1_Spt5_2         1           ctrl  hs3a-3b      noise2
# 20  TriC_10_lane_1_Spt5_2         1           ctrl  hs3a-3b  IgG2a+-3kb
# 21  TriC_10_lane_1_Spt5_2         1           ctrl  3CBEhs4         mu+
# 22  TriC_10_lane_1_Spt5_2         1           ctrl  3CBEhs4      noise2
# 23  TriC_10_lane_1_Spt5_2         1           ctrl  3CBEhs4  IgG2a+-3kb
# 24  TriC_10_lane_1_Spt5_2         2           ctrl  hs3a-3b         mu+
# 25  TriC_10_lane_1_Spt5_2         2           ctrl  hs3a-3b      noise2
# 26  TriC_10_lane_1_Spt5_2         2           ctrl  hs3a-3b  IgG2a+-3kb
# 27  TriC_10_lane_1_Spt5_2         2           ctrl  3CBEhs4         mu+
# 28  TriC_10_lane_1_Spt5_2         2           ctrl  3CBEhs4      noise2
# 29  TriC_10_lane_1_Spt5_2         2           ctrl  3CBEhs4  IgG2a+-3kb
# 30      TriC8_lane_2_Spt5         3             KO  hs3a-3b         mu+
# 31      TriC8_lane_2_Spt5         3             KO  hs3a-3b      noise2
# 32      TriC8_lane_2_Spt5         3             KO  hs3a-3b  IgG2a+-3kb
# 33      TriC8_lane_2_Spt5         3             KO  3CBEhs4         mu+
# 34      TriC8_lane_2_Spt5         3             KO  3CBEhs4      noise2
# 35      TriC8_lane_2_Spt5         3             KO  3CBEhs4  IgG2a+-3kb
# 36      TriC8_lane_2_Spt5         4             KO  hs3a-3b         mu+
# 37      TriC8_lane_2_Spt5         4             KO  hs3a-3b      noise2
# 38      TriC8_lane_2_Spt5         4             KO  hs3a-3b  IgG2a+-3kb
# 39      TriC8_lane_2_Spt5         4             KO  3CBEhs4         mu+
# 40      TriC8_lane_2_Spt5         4             KO  3CBEhs4      noise2
# 41      TriC8_lane_2_Spt5         4             KO  3CBEhs4  IgG2a+-3kb
# 42      TriC8_lane_2_Spt5         1           ctrl  hs3a-3b         mu+
# 43      TriC8_lane_2_Spt5         1           ctrl  hs3a-3b      noise2
# 44      TriC8_lane_2_Spt5         1           ctrl  hs3a-3b  IgG2a+-3kb
# 45      TriC8_lane_2_Spt5         1           ctrl  3CBEhs4         mu+
# 46      TriC8_lane_2_Spt5         1           ctrl  3CBEhs4      noise2
# 47      TriC8_lane_2_Spt5         1           ctrl  3CBEhs4  IgG2a+-3kb
# 48      TriC8_lane_2_Spt5         3           ctrl  hs3a-3b         mu+
# 49      TriC8_lane_2_Spt5         3           ctrl  hs3a-3b      noise2
# 50      TriC8_lane_2_Spt5         3           ctrl  hs3a-3b  IgG2a+-3kb
# 51      TriC8_lane_2_Spt5         3           ctrl  3CBEhs4         mu+
# 52      TriC8_lane_2_Spt5         3           ctrl  3CBEhs4      noise2
# 53      TriC8_lane_2_Spt5         3           ctrl  3CBEhs4  IgG2a+-3kb
#
#     pinteractions            regioncomb
# 0        1.685040         hs3a-3b - mu+
# 1        0.845149      hs3a-3b - noise2
# 2        1.393537  hs3a-3b - IgG2a+-3kb
# 3        2.704615         3CBEhs4 - mu+
# 4        1.008750      3CBEhs4 - noise2
# 5        0.410989  3CBEhs4 - IgG2a+-3kb
# 6        1.512421         hs3a-3b - mu+
# 7        0.795595      hs3a-3b - noise2
# 8        0.688980  hs3a-3b - IgG2a+-3kb
# 9        4.051282         3CBEhs4 - mu+
# 10       1.026875      3CBEhs4 - noise2
# 11       1.305989  3CBEhs4 - IgG2a+-3kb
# 12       1.655913         hs3a-3b - mu+
# 13       0.741280      hs3a-3b - noise2
# 14       1.823367  hs3a-3b - IgG2a+-3kb
# 15       3.242308         3CBEhs4 - mu+
# 16       1.587837      3CBEhs4 - noise2
# 17       0.217527  3CBEhs4 - IgG2a+-3kb
# 18       1.321667         hs3a-3b - mu+
# 19       0.102083      hs3a-3b - noise2
# 20       0.335102  hs3a-3b - IgG2a+-3kb
# 21       5.516346         3CBEhs4 - mu+
# 22       2.256827      3CBEhs4 - noise2
# 23       1.296209  3CBEhs4 - IgG2a+-3kb
# 24       0.811349         hs3a-3b - mu+
# 25       0.040744      hs3a-3b - noise2
# 26       0.185306  hs3a-3b - IgG2a+-3kb
# 27       2.746923         3CBEhs4 - mu+
# 28       0.754615      3CBEhs4 - noise2
# 29       0.157198  3CBEhs4 - IgG2a+-3kb
# 30       1.570357         hs3a-3b - mu+
# 31       1.127173      hs3a-3b - noise2
# 32       0.973707  hs3a-3b - IgG2a+-3kb
# 33       2.683590         3CBEhs4 - mu+
# 34       0.823798      3CBEhs4 - noise2
# 35       0.069615  3CBEhs4 - IgG2a+-3kb
# 36       1.750635         hs3a-3b - mu+
# 37       0.788988      hs3a-3b - noise2
# 38       1.570918  hs3a-3b - IgG2a+-3kb
# 39       5.062628         3CBEhs4 - mu+
# 40       0.685048      3CBEhs4 - noise2
# 41       0.895385  3CBEhs4 - IgG2a+-3kb
# 42       3.701190         hs3a-3b - mu+
# 43       0.473958      hs3a-3b - noise2
# 44       0.346769  hs3a-3b - IgG2a+-3kb
# 45      10.899615         3CBEhs4 - mu+
# 46       1.062500      3CBEhs4 - noise2
# 47       1.187253  3CBEhs4 - IgG2a+-3kb
# 48       1.411032         hs3a-3b - mu+
# 49       0.365030      hs3a-3b - noise2
# 50       0.914626  hs3a-3b - IgG2a+-3kb
# 51       4.717436         3CBEhs4 - mu+
# 52       0.279423      3CBEhs4 - noise2
# 53       0.679560  3CBEhs4 - IgG2a+-3kb

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(20,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10


ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax, bottom=0.001)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'IgG1_pool_capture -- {region1} -- x')
	ax.set_ylim(0.01)
fig.suptitle('TriC8&10_mm9Spt5 interactions')

fig.savefig('../plots/TriC10/TriC8&10_mm9Spt5_RegOfInterest_IgG1poolCap_randIA.pdf')
# Out:
# noise2_KO v.s. noise2_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.512e-01
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=5.324e-01 stat=-1.499e+00
# IgG2a+-3kb_KO v.s. IgG2a+-3kb_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-7.220e-01
# noise2_KO v.s. noise2_ctrl: t-test independent samples with Bonferroni correction, P_val=4.107e-03 stat=5.120e+00
# mu+_KO v.s. mu+_ctrl: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-3.110e-01
# IgG2a+-3kb_KO v.s. IgG2a+-3kb_ctrl: t-test independent samples with Bonferroni correction, P_val=5.102e-02 stat=3.113e+00

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_10.tsv' '../resource/sampleinfo_TriC_8_noVDJnoSort_rerun.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'CG2b-5prhs3a' -r2 'CG2b-5prhs3a' \
	--prefix 'TriC_10_lane_1_Spt5' 'TriC8_lane_2_Spt5' \
	--dir '../TriCplots/TriC10_mapq20_TriC8_mapq20_rerun' --capture 'IgG1_pool_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums
# Out:
#                   sample replicate treatment_time       region1       region2  \
# 0  TriC_10_lane_1_Spt5_2         1             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 1  TriC_10_lane_1_Spt5_2         2             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 2  TriC_10_lane_1_Spt5_2         3             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 3  TriC_10_lane_1_Spt5_2         1           ctrl  CG2b-5prhs3a  CG2b-5prhs3a
# 4  TriC_10_lane_1_Spt5_2         2           ctrl  CG2b-5prhs3a  CG2b-5prhs3a
# 5      TriC8_lane_2_Spt5         3             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 6      TriC8_lane_2_Spt5         4             KO  CG2b-5prhs3a  CG2b-5prhs3a
# 7      TriC8_lane_2_Spt5         1           ctrl  CG2b-5prhs3a  CG2b-5prhs3a
# 8      TriC8_lane_2_Spt5         3           ctrl  CG2b-5prhs3a  CG2b-5prhs3a
#
#    pinteractions                   regioncomb
# 0      16.122272  CG2b-5prhs3a - CG2b-5prhs3a
# 1      17.281440  CG2b-5prhs3a - CG2b-5prhs3a
# 2      17.626620  CG2b-5prhs3a - CG2b-5prhs3a
# 3      13.119460  CG2b-5prhs3a - CG2b-5prhs3a
# 4      13.134800  CG2b-5prhs3a - CG2b-5prhs3a
# 5      19.233800  CG2b-5prhs3a - CG2b-5prhs3a
# 6      17.501876  CG2b-5prhs3a - CG2b-5prhs3a
# 7      10.987356  CG2b-5prhs3a - CG2b-5prhs3a
# 8      14.747396  CG2b-5prhs3a - CG2b-5prhs3a

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(10,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10


ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax, bottom=0.001)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'IgG1_pool_capture -- {region1} -- x')
	ax.set_ylim(0.01)
fig.suptitle('TriC8&10_mm9Spt5 interactions')

fig.savefig('../plots/TriC10/TriC8&10_mm9Spt5_RegOfInterest_IgG1poolCap_randIATri_log.pdf')
# Out:
# CG2b-5prhs3a_KO v.s. CG2b-5prhs3a_ctrl: t-test independent samples with Bonferroni correction, P_val=1.298e-03 stat=5.168e+00
