# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
# pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC17mm9.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'mu+' 'ISCgG3+-3kb' '3CBE3RR' -r2 'mu+' 'ISCgG3+-3kb' '3CBE3RR' \
	--prefix 'TriC17_priB_B18AIDKO_LPS_igg3' \
	--dir '../TriCplots/TriC17_mapq20' --capture 'IgG3_pool_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums = contactsums[::-1]
contactsums
# Out:
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                            sample replicate treatment_time      region1  \
# 35  TriC17_priB_B18AIDKO_LPS_igg3         3             d3      3CBE3RR
# 34  TriC17_priB_B18AIDKO_LPS_igg3         3             d3      3CBE3RR
# 33  TriC17_priB_B18AIDKO_LPS_igg3         3             d3      3CBE3RR
# 32  TriC17_priB_B18AIDKO_LPS_igg3         3             d3  ISCgG3+-3kb
# 31  TriC17_priB_B18AIDKO_LPS_igg3         3             d3  ISCgG3+-3kb
# 30  TriC17_priB_B18AIDKO_LPS_igg3         3             d3          mu+
# 29  TriC17_priB_B18AIDKO_LPS_igg3         1             d0      3CBE3RR
# 28  TriC17_priB_B18AIDKO_LPS_igg3         1             d0      3CBE3RR
# 27  TriC17_priB_B18AIDKO_LPS_igg3         1             d0      3CBE3RR
# 26  TriC17_priB_B18AIDKO_LPS_igg3         1             d0  ISCgG3+-3kb
# 25  TriC17_priB_B18AIDKO_LPS_igg3         1             d0  ISCgG3+-3kb
# 24  TriC17_priB_B18AIDKO_LPS_igg3         1             d0          mu+
# 23  TriC17_priB_B18AIDKO_LPS_igg3         2             d0      3CBE3RR
# 22  TriC17_priB_B18AIDKO_LPS_igg3         2             d0      3CBE3RR
# 21  TriC17_priB_B18AIDKO_LPS_igg3         2             d0      3CBE3RR
# 20  TriC17_priB_B18AIDKO_LPS_igg3         2             d0  ISCgG3+-3kb
# 19  TriC17_priB_B18AIDKO_LPS_igg3         2             d0  ISCgG3+-3kb
# 18  TriC17_priB_B18AIDKO_LPS_igg3         2             d0          mu+
# 17  TriC17_priB_B18AIDKO_LPS_igg3         2             d3      3CBE3RR
# 16  TriC17_priB_B18AIDKO_LPS_igg3         2             d3      3CBE3RR
# 15  TriC17_priB_B18AIDKO_LPS_igg3         2             d3      3CBE3RR
# 14  TriC17_priB_B18AIDKO_LPS_igg3         2             d3  ISCgG3+-3kb
# 13  TriC17_priB_B18AIDKO_LPS_igg3         2             d3  ISCgG3+-3kb
# 12  TriC17_priB_B18AIDKO_LPS_igg3         2             d3          mu+
# 11  TriC17_priB_B18AIDKO_LPS_igg3         3             d0      3CBE3RR
# 10  TriC17_priB_B18AIDKO_LPS_igg3         3             d0      3CBE3RR
# 9   TriC17_priB_B18AIDKO_LPS_igg3         3             d0      3CBE3RR
# 8   ISCgG3+-3kb     255.023418  ISCgG3+-3kb - ISCgG3+-3kb
# 7           mu+      12.639405          ISCgG3+-3kb - mu+
# 6           mu+      67.147917                  mu+ - mu+
# 5       3CBE3RR      15.940020          3CBE3RR - 3CBE3RR
# 4   ISCgG3+-3kb       7.102637      3CBE3RR - ISCgG3+-3kb
# 3           mu+       3.539744              3CBE3RR - mu+
# 2   ISCgG3+-3kb     269.640459  ISCgG3+-3kb - ISCgG3+-3kb
# 1           mu+       5.882500          ISCgG3+-3kb - mu+
# 0           mu+     128.598681                  mu+ - mu+

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', 
		box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2, line_offset=0.3, line_offset_to_box=0.2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'IgG3pool_capture -- {region1} -- x')
fig.suptitle('TriC17_mm9AIDKO-LPS IgG3pool interactions')

fig.savefig('../plots/TriC17/TriC17_mm9AIDKO-LPS_RegOfInterest_IgG3poolCap_allZones.pdf')
# Out:
# ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=9.010e-01 stat=1.189e+00
# 3CBE3RR_d3 v.s. 3CBE3RR_d0: t-test independent samples with Bonferroni correction, P_val=1.649e-01 stat=2.685e+00
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.635e-01 stat=2.693e+00
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=5.255e-01
# ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.048e-01 stat=2.731e+00
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=5.325e-01 stat=6.824e-01

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

region_order = ['mu+ - mu+', 'ISCgG3+-3kb - mu+', '3CBE3RR - mu+', 'ISCgG3+-3kb - ISCgG3+-3kb', '3CBE3RR - ISCgG3+-3kb', '3CBE3RR - 3CBE3RR']

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5

# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
ax = fig.add_subplot(111, yscale = 'log')
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, order=region_order, ax=ax, bottom=0.001)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	order=region_order, palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2)

handles, labels = ax.get_legend_handles_labels()
# ax.legend_.remove()
# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
ax.set_ylabel('log(Interactions norm. by N of bins)')
ax.set_xlabel("x regions")
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
ax.set_title(f'IgG3pool_capture -- x')
fig.suptitle('TriC17_mm9AIDKO-LPS IgG3pool interactions')
ax.set_ylim(1)

fig.savefig('../plots/TriC17/TriC17_mm9AIDKO-LPS_RegOfInterest_IgG3poolCap_allZones_combined.pdf')
# Out:
# ISCgG3+-3kb - mu+_d3 v.s. ISCgG3+-3kb - mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=5.255e-01
# mu+ - mu+_d3 v.s. mu+ - mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=6.824e-01
# 3CBE3RR - mu+_d3 v.s. 3CBE3RR - mu+_d0: t-test independent samples with Bonferroni correction, P_val=3.270e-01 stat=2.693e+00
# 3CBE3RR - 3CBE3RR_d3 v.s. 3CBE3RR - 3CBE3RR_d0: t-test independent samples with Bonferroni correction, P_val=3.298e-01 stat=2.685e+00
# 3CBE3RR - ISCgG3+-3kb_d3 v.s. 3CBE3RR - ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.189e+00
# ISCgG3+-3kb - ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb - ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=3.143e-01 stat=2.731e+00
