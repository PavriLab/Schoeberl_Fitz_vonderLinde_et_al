# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
from statannotations.Annotator import Annotator

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_8_noVDJnoSort_rerun.tsv' '../resource/sampleinfo_TriC_8_noVDJnoSort_rerun.tsv' -r '../resource/regions_of_interest_Ramos.tsv' \
	-r1 '3RRCBE2' '3RRCBE1' 'mu-4kb' -r2 '3RRCBE1' 'Ed+-2kb' 'mu-4kb' \
	--prefix 'TriC8_lane_1_RamosAIDKO_D3' 'TriC8_lane_1_Ramos_RIEP' --dir '../TriCplots/TriC8_mapq30_rerun' --capture '5Smu_capture' \
	--genome 'hg38' --igh 105550000 105866000 --selfInt
contactsums1 = contactsums.copy()
contactsums1
# Out:
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                      sample replicate treatment_time  region1  region2  \
# 0   TriC8_lane_1_RamosAIDKO         1             D3  3RRCBE2  3RRCBE1
# 1   TriC8_lane_1_RamosAIDKO         1             D3  3RRCBE2  Ed+-2kb
# 2   TriC8_lane_1_RamosAIDKO         1             D3  3RRCBE2   mu-4kb
# 3   TriC8_lane_1_RamosAIDKO         1             D3  3RRCBE1  3RRCBE1
# 4   TriC8_lane_1_RamosAIDKO         1             D3  3RRCBE1  Ed+-2kb
# 5   TriC8_lane_1_RamosAIDKO         1             D3  3RRCBE1   mu-4kb
# 6   TriC8_lane_1_RamosAIDKO         1             D3   mu-4kb   mu-4kb
# 7   TriC8_lane_1_RamosAIDKO         2             D3  3RRCBE2  3RRCBE1
# 8   TriC8_lane_1_RamosAIDKO         2             D3  3RRCBE2  Ed+-2kb
# 9   TriC8_lane_1_RamosAIDKO         2             D3  3RRCBE2   mu-4kb
# 10  TriC8_lane_1_RamosAIDKO         2             D3  3RRCBE1  3RRCBE1
# 11  TriC8_lane_1_RamosAIDKO         2             D3  3RRCBE1  Ed+-2kb
# 12  TriC8_lane_1_RamosAIDKO         2             D3  3RRCBE1   mu-4kb
# 13  TriC8_lane_1_RamosAIDKO         2             D3   mu-4kb   mu-4kb
# 14  TriC8_lane_1_RamosAIDKO         3             D3  3RRCBE2  3RRCBE1
# 15  TriC8_lane_1_RamosAIDKO         3             D3  3RRCBE2  Ed+-2kb
# 16  TriC8_lane_1_RamosAIDKO         3             D3  3RRCBE2   mu-4kb
# 17  TriC8_lane_1_RamosAIDKO         3             D3  3RRCBE1  3RRCBE1
# 18  TriC8_lane_1_RamosAIDKO         3             D3  3RRCBE1  Ed+-2kb
# 19  TriC8_lane_1_RamosAIDKO         3             D3  3RRCBE1   mu-4kb
# 20  TriC8_lane_1_RamosAIDKO         3             D3   mu-4kb   mu-4kb
# 21       TriC8_lane_1_Ramos         1           RIEP  3RRCBE2  3RRCBE1
# 22       TriC8_lane_1_Ramos         1           RIEP  3RRCBE2  Ed+-2kb
# 23       TriC8_lane_1_Ramos         1           RIEP  3RRCBE2   mu-4kb
# 24       TriC8_lane_1_Ramos         1           RIEP  3RRCBE1  3RRCBE1
# 25       TriC8_lane_1_Ramos         1           RIEP  3RRCBE1  Ed+-2kb
# 26       TriC8_lane_1_Ramos         1           RIEP  3RRCBE1   mu-4kb
# 27       TriC8_lane_1_Ramos         1           RIEP   mu-4kb   mu-4kb
# 28       TriC8_lane_1_Ramos         2           RIEP  3RRCBE2  3RRCBE1
# 29       TriC8_lane_1_Ramos         2           RIEP  3RRCBE2  Ed+-2kb
# 30       TriC8_lane_1_Ramos         2           RIEP  3RRCBE2   mu-4kb
# 31       TriC8_lane_1_Ramos         2           RIEP  3RRCBE1  3RRCBE1
# 32       TriC8_lane_1_Ramos         2           RIEP  3RRCBE1  Ed+-2kb
# 33       TriC8_lane_1_Ramos         2           RIEP  3RRCBE1   mu-4kb
# 34       TriC8_lane_1_Ramos         2           RIEP   mu-4kb   mu-4kb
# 35       TriC8_lane_1_Ramos         3           RIEP  3RRCBE2  3RRCBE1
# 36       TriC8_lane_1_Ramos         3           RIEP  3RRCBE2  Ed+-2kb
# 37       TriC8_lane_1_Ramos         3           RIEP  3RRCBE2   mu-4kb
# 38       TriC8_lane_1_Ramos         3           RIEP  3RRCBE1  3RRCBE1
# 39       TriC8_lane_1_Ramos         3           RIEP  3RRCBE1  Ed+-2kb
# 40       TriC8_lane_1_Ramos         3           RIEP  3RRCBE1   mu-4kb
# 41       TriC8_lane_1_Ramos         3           RIEP   mu-4kb   mu-4kb
#
#     pinteractions         regioncomb
# 0       20.025067  3RRCBE2 - 3RRCBE1
# 1        3.563467  3RRCBE2 - Ed+-2kb
# 2       37.743889   3RRCBE2 - mu-4kb
# 3       90.771867  3RRCBE1 - 3RRCBE1
# 4       13.016000  3RRCBE1 - Ed+-2kb
# 5       17.702222   3RRCBE1 - mu-4kb
# 6     3055.805000    mu-4kb - mu-4kb
# 7       38.858756  3RRCBE2 - 3RRCBE1
# 8        1.211067  3RRCBE2 - Ed+-2kb
# 9       54.349111   3RRCBE2 - mu-4kb
# 10      59.551156  3RRCBE1 - 3RRCBE1
# 11      14.442933  3RRCBE1 - Ed+-2kb
# 12      90.829444   3RRCBE1 - mu-4kb
# 13    2354.581111    mu-4kb - mu-4kb
# 14      18.748667  3RRCBE2 - 3RRCBE1
# 15       0.000000  3RRCBE2 - Ed+-2kb
# 16       4.325111   3RRCBE2 - mu-4kb
# 17      81.231600  3RRCBE1 - 3RRCBE1
# 18       1.560133  3RRCBE1 - Ed+-2kb
# 19      13.691444   3RRCBE1 - mu-4kb
# 20    2451.301389    mu-4kb - mu-4kb
# 21      29.712222  3RRCBE2 - 3RRCBE1
# 22       3.400533  3RRCBE2 - Ed+-2kb
# 23       2.187889   3RRCBE2 - mu-4kb
# 24      68.125867  3RRCBE1 - 3RRCBE1
# 25       9.384267  3RRCBE1 - Ed+-2kb
# 26      35.630667   3RRCBE1 - mu-4kb
# 27    2574.533056    mu-4kb - mu-4kb
# 28      21.483733  3RRCBE2 - 3RRCBE1
# 29       2.099733  3RRCBE2 - Ed+-2kb
# 30      19.780667   3RRCBE2 - mu-4kb
# 31      65.608622  3RRCBE1 - 3RRCBE1
# 32       2.764667  3RRCBE1 - Ed+-2kb
# 33      21.738333   3RRCBE1 - mu-4kb
# 34    2505.904722    mu-4kb - mu-4kb
# 35      39.219822  3RRCBE2 - 3RRCBE1
# 36       0.603067  3RRCBE2 - Ed+-2kb
# 37      15.406000   3RRCBE2 - mu-4kb
# 38     101.714844  3RRCBE1 - 3RRCBE1
# 39      16.684267  3RRCBE1 - Ed+-2kb
# 40      27.903889   3RRCBE1 - mu-4kb
# 41    2323.504444    mu-4kb - mu-4kb

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_10_noVDJ.tsv' '../resource/sampleinfo_TriC_10_noVDJ.tsv' -r '../resource/regions_of_interest_Ramos.tsv' \
	-r1 '3RRCBE2' '3RRCBE1' 'mu-4kb' -r2 '3RRCBE1' 'Ed+-2kb' 'mu-4kb' \
	--prefix 'TriC_10_lane_2_Ramos2_D3' 'TriC_10_lane_2_Ramos2_RIEP' --dir '../TriCplots/TriC10_mapq30' --capture '5Smu_capture' \
	--genome 'hg38' --igh 105550000 105866000 --selfInt
contactsums2 = contactsums.copy()
contactsums2
# Out:
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                    sample replicate treatment_time  region1  region2  \
# 0   TriC_10_lane_2_Ramos2         1             D3  3RRCBE2  3RRCBE1
# 1   TriC_10_lane_2_Ramos2         1             D3  3RRCBE2  Ed+-2kb
# 2   TriC_10_lane_2_Ramos2         1             D3  3RRCBE2   mu-4kb
# 3   TriC_10_lane_2_Ramos2         1             D3  3RRCBE1  3RRCBE1
# 4   TriC_10_lane_2_Ramos2         1             D3  3RRCBE1  Ed+-2kb
# 5   TriC_10_lane_2_Ramos2         1             D3  3RRCBE1   mu-4kb
# 6   TriC_10_lane_2_Ramos2         1             D3   mu-4kb   mu-4kb
# 7   TriC_10_lane_2_Ramos2         2             D3  3RRCBE2  3RRCBE1
# 8   TriC_10_lane_2_Ramos2         2             D3  3RRCBE2  Ed+-2kb
# 9   TriC_10_lane_2_Ramos2         2             D3  3RRCBE2   mu-4kb
# 10  TriC_10_lane_2_Ramos2         2             D3  3RRCBE1  3RRCBE1
# 11  TriC_10_lane_2_Ramos2         2             D3  3RRCBE1  Ed+-2kb
# 12  TriC_10_lane_2_Ramos2         2             D3  3RRCBE1   mu-4kb
# 13  TriC_10_lane_2_Ramos2         2             D3   mu-4kb   mu-4kb
# 14  TriC_10_lane_2_Ramos2         3             D3  3RRCBE2  3RRCBE1
# 15  TriC_10_lane_2_Ramos2         3             D3  3RRCBE2  Ed+-2kb
# 16  TriC_10_lane_2_Ramos2         3             D3  3RRCBE2   mu-4kb
# 17  TriC_10_lane_2_Ramos2         3             D3  3RRCBE1  3RRCBE1
# 18  TriC_10_lane_2_Ramos2         3             D3  3RRCBE1  Ed+-2kb
# 19  TriC_10_lane_2_Ramos2         3             D3  3RRCBE1   mu-4kb
# 20  TriC_10_lane_2_Ramos2         3             D3   mu-4kb   mu-4kb
# 21  TriC_10_lane_2_Ramos2         1           RIEP  3RRCBE2  3RRCBE1
# 22  TriC_10_lane_2_Ramos2         1           RIEP  3RRCBE2  Ed+-2kb
# 23  TriC_10_lane_2_Ramos2         1           RIEP  3RRCBE2   mu-4kb
# 24  TriC_10_lane_2_Ramos2         1           RIEP  3RRCBE1  3RRCBE1
# 25  TriC_10_lane_2_Ramos2         1           RIEP  3RRCBE1  Ed+-2kb
# 26  TriC_10_lane_2_Ramos2         1           RIEP  3RRCBE1   mu-4kb
# 27  TriC_10_lane_2_Ramos2         1           RIEP   mu-4kb   mu-4kb
# 28  TriC_10_lane_2_Ramos2         2           RIEP  3RRCBE2  3RRCBE1
# 29  TriC_10_lane_2_Ramos2         2           RIEP  3RRCBE2  Ed+-2kb
# 30  TriC_10_lane_2_Ramos2         2           RIEP  3RRCBE2   mu-4kb
# 31  TriC_10_lane_2_Ramos2         2           RIEP  3RRCBE1  3RRCBE1
# 32  TriC_10_lane_2_Ramos2         2           RIEP  3RRCBE1  Ed+-2kb
# 33  TriC_10_lane_2_Ramos2         2           RIEP  3RRCBE1   mu-4kb
# 34  TriC_10_lane_2_Ramos2         2           RIEP   mu-4kb   mu-4kb
# 35  TriC_10_lane_2_Ramos2         3           RIEP  3RRCBE2  3RRCBE1
# 36  TriC_10_lane_2_Ramos2         3           RIEP  3RRCBE2  Ed+-2kb
# 37  TriC_10_lane_2_Ramos2         3           RIEP  3RRCBE2   mu-4kb
# 38  TriC_10_lane_2_Ramos2         3           RIEP  3RRCBE1  3RRCBE1
# 39  TriC_10_lane_2_Ramos2         3           RIEP  3RRCBE1  Ed+-2kb
# 40  TriC_10_lane_2_Ramos2         3           RIEP  3RRCBE1   mu-4kb
# 41  TriC_10_lane_2_Ramos2         3           RIEP   mu-4kb   mu-4kb
#
#     pinteractions         regioncomb
# 0       13.446578  3RRCBE2 - 3RRCBE1
# 1       10.366400  3RRCBE2 - Ed+-2kb
# 2        8.563333   3RRCBE2 - mu-4kb
# 3       71.611733  3RRCBE1 - 3RRCBE1
# 4       10.651333  3RRCBE1 - Ed+-2kb
# 5       23.387778   3RRCBE1 - mu-4kb
# 6     2338.508889    mu-4kb - mu-4kb
# 7       30.721822  3RRCBE2 - 3RRCBE1
# 8        2.346000  3RRCBE2 - Ed+-2kb
# 9       12.863556   3RRCBE2 - mu-4kb
# 10      70.914978  3RRCBE1 - 3RRCBE1
# 11      17.874267  3RRCBE1 - Ed+-2kb
# 12      20.894889   3RRCBE1 - mu-4kb
# 13    2328.597778    mu-4kb - mu-4kb
# 14      12.542089  3RRCBE2 - 3RRCBE1
# 15       6.554133  3RRCBE2 - Ed+-2kb
# 16      19.526000   3RRCBE2 - mu-4kb
# 17      55.922489  3RRCBE1 - 3RRCBE1
# 18       0.224667  3RRCBE1 - Ed+-2kb
# 19      12.216667   3RRCBE1 - mu-4kb
# 20    3211.918056    mu-4kb - mu-4kb
# 21      26.008933  3RRCBE2 - 3RRCBE1
# 22       0.000000  3RRCBE2 - Ed+-2kb
# 23      14.124111   3RRCBE2 - mu-4kb
# 24      59.084000  3RRCBE1 - 3RRCBE1
# 25       2.360400  3RRCBE1 - Ed+-2kb
# 26      25.163667   3RRCBE1 - mu-4kb
# 27    3000.240000    mu-4kb - mu-4kb
# 28      17.806978  3RRCBE2 - 3RRCBE1
# 29       8.206000  3RRCBE2 - Ed+-2kb
# 30      32.754556   3RRCBE2 - mu-4kb
# 31      47.477422  3RRCBE1 - 3RRCBE1
# 32      10.450800  3RRCBE1 - Ed+-2kb
# 33      14.179111   3RRCBE1 - mu-4kb
# 34    2563.594444    mu-4kb - mu-4kb
# 35      41.970000  3RRCBE2 - 3RRCBE1
# 36       2.357867  3RRCBE2 - Ed+-2kb
# 37      13.847889   3RRCBE2 - mu-4kb
# 38      87.325333  3RRCBE1 - 3RRCBE1
# 39       2.070267  3RRCBE1 - Ed+-2kb
# 40      39.631889   3RRCBE1 - mu-4kb
# 41    2003.051111    mu-4kb - mu-4kb

# %%
region_order = ['3RRCBE1 - mu-4kb', '3RRCBE2 - mu-4kb', '3RRCBE1 - Ed+-2kb', '3RRCBE2 - Ed+-2kb', '3RRCBE2 - 3RRCBE1']
contactsums = pd.concat([contactsums1, contactsums2])
contactsums = contactsums.replace({'TriC8_lane_1_RamosAIDKO': 'TriC8', 'TriC8_lane_1_Ramos': 'TriC8', 'TriC_10_lane_2_Ramos2': 'TriC10'})
contactsumsSelf = contactsums.loc[contactsums['regioncomb'] == 'mu-4kb - mu-4kb'] # isolate zone 1
contactsums = contactsums.loc[contactsums['regioncomb'].isin(region_order)] # remove any self interaction zones
contactsums = contactsums.sort_values('treatment_time')

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5


fig = plt.figure(figsize=(15,10))
maxInteraction = max(contactsums['pinteractions'])
maxInteraction = maxInteraction + maxInteraction/10

markerlist = ['o', 'P']

ax1 = fig.add_subplot(1, 6, 1)
sns.barplot(data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax1)
markerCounter = 0
for (sampleName, group2) in contactsumsSelf.groupby('sample'):
	sns.stripplot(data=group2, x='regioncomb', y='pinteractions', hue='treatment_time', marker=markerlist[markerCounter], ax=ax1, dodge=True, size=10,
		palette=['black', 'red'])
	markerCounter +=1

boxlist = [] # list with pairs for statistical significance test
for reg in contactsumsSelf['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsumsSelf['treatment_time'].unique()[0]), (reg, contactsumsSelf['treatment_time'].unique()[1]))]
annot = Annotator(ax1, data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', pairs=boxlist)
annot.configure(test='t-test_ind', text_format='simple', verbose=5, comparisons_correction="BH") #
annot.apply_and_annotate()

ax1.legend_.remove()
ax1.set_ylabel('Interactions norm. by N of bins')
ax1.set_xlabel('')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15)



ax = fig.add_subplot(1, 6, (2, 6))
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax, order=region_order)
markerCounter = 0
for (sampleName, group2) in contactsums.groupby('sample'):
	sns.stripplot(data=group2, x='regioncomb', y='pinteractions', hue='treatment_time', marker=markerlist[markerCounter], ax=ax, dodge=True, size=10,
		palette=['black', 'red'], order=region_order)
	markerCounter +=1

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
annot = Annotator(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', pairs=boxlist, order=region_order)
annot.configure(test='t-test_ind', text_format='simple', verbose=5, comparisons_correction="BH") #
annot.apply_and_annotate()

f = lambda m,c: plt.plot([],[],marker=m, color=c, ls="none")[0]
handles, labels = ax.get_legend_handles_labels()
handles += [f(list(dict.fromkeys(markerlist))[i], "k") for i in range(len(dict.fromkeys(markerlist)))]
labels += list(contactsums['sample'].unique())
ax.legend(handles, labels)
ax.set_ylim(0, maxInteraction)
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
fig.suptitle(f"5Smu_capture -- x")

fig.savefig('../plots/TriC10/TriC8-10_RamosD3-RIEP_RegOfInterest_markers.pdf')
# Out:
# mu-4kb - mu-4kb_D3 vs. mu-4kb - mu-4kb_RIEP: t-test independent samples with Benjamini-Hochberg correction, P_val:5.575e-01 t=6.069e-01
# 3RRCBE2 - mu-4kb_D3 vs. 3RRCBE2 - mu-4kb_RIEP: t-test independent samples with Benjamini-Hochberg correction, P_val:4.780e-01 t=7.370e-01
# 3RRCBE1 - mu-4kb_D3 vs. 3RRCBE1 - mu-4kb_RIEP: t-test independent samples with Benjamini-Hochberg correction, P_val:8.553e-01 t=1.871e-01
# 3RRCBE1 - Ed+-2kb_D3 vs. 3RRCBE1 - Ed+-2kb_RIEP: t-test independent samples with Benjamini-Hochberg correction, P_val:5.508e-01 t=6.174e-01
# 3RRCBE2 - 3RRCBE1_D3 vs. 3RRCBE2 - 3RRCBE1_RIEP: t-test independent samples with Benjamini-Hochberg correction, P_val:2.546e-01 t=-1.209e+00
# 3RRCBE2 - Ed+-2kb_D3 vs. 3RRCBE2 - Ed+-2kb_RIEP: t-test independent samples with Benjamini-Hochberg correction, P_val:5.471e-01 t=6.231e-01

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5


fig = plt.figure(figsize=(15,10))
maxInteraction = max(contactsums['pinteractions'])
maxInteraction = maxInteraction + maxInteraction/10

markerlist = ['o', 'P', 'X', '*']

ax1 = fig.add_subplot(1, 6, 1)
sns.barplot(data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax1)
sns.stripplot(data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax1, dodge=True, size=10,
	palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsumsSelf['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsumsSelf['treatment_time'].unique()[0]), (reg, contactsumsSelf['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax1, data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2)

ax1.legend_.remove()
ax1.set_ylabel('Interactions norm. by N of bins')
ax1.set_xlabel('')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15)



ax = fig.add_subplot(1, 6, (2, 6))
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax, order=region_order)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	palette=['black', 'red'], order=region_order)

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2)

ax.set_ylim(0, maxInteraction)
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
fig.suptitle(f"5Smu_capture -- x")

# fig.savefig('../plots/TriC17/TriC17_RamosTRE3GG3_RegOfInterest.pdf')
# Out:
# mu-4kb - mu-4kb_D3 v.s. mu-4kb - mu-4kb_RIEP: t-test independent samples with Bonferroni correction, P_val=5.575e-01 stat=6.069e-01
# 3RRCBE2 - mu-4kb_D3 v.s. 3RRCBE2 - mu-4kb_RIEP: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=7.370e-01
# 3RRCBE1 - mu-4kb_D3 v.s. 3RRCBE1 - mu-4kb_RIEP: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.871e-01
# 3RRCBE1 - Ed+-2kb_D3 v.s. 3RRCBE1 - Ed+-2kb_RIEP: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=6.174e-01
# 3RRCBE2 - 3RRCBE1_D3 v.s. 3RRCBE2 - 3RRCBE1_RIEP: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.209e+00
# 3RRCBE2 - Ed+-2kb_D3 v.s. 3RRCBE2 - Ed+-2kb_RIEP: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=6.231e-01
# Text(0.5, 0.98, '5Smu_capture -- x')
