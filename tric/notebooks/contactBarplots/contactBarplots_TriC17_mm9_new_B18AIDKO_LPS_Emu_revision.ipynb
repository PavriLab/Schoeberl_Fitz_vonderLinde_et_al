# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot
# pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC17mm9.tsv' -r '../resource/regions_of_interest_mm9.tsv' \
	-r1 'mu+' 'ISCgG3+-3kb' 'ISCEgamma1+-5kb' '3CBE3RR' -r2 'mu+' 'ISCgG3+-3kb' 'ISCEgamma1+-5kb' '3CBE3RR' \
	--prefix 'TriC17_priB_B18AIDKO_LPS_emu' \
	--dir '../TriCplots/TriC17_mapq20' --capture 'Emu_capture' --genome 'mm9' --igh 114435000 114669000 --selfInt
contactsums = contactsums[::-1]
contactsums
# Out:
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCgG3+-3kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu+ with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 ISCEgamma1+-5kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCgG3+-3kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 ISCEgamma1+-5kb with region2 3CBE3RR was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                           sample replicate treatment_time          region1  \
# 59  TriC17_priB_B18AIDKO_LPS_emu         3             d3          3CBE3RR
# 58  TriC17_priB_B18AIDKO_LPS_emu         3             d3          3CBE3RR
# 57  TriC17_priB_B18AIDKO_LPS_emu         3             d3          3CBE3RR
# 56  TriC17_priB_B18AIDKO_LPS_emu         3             d3          3CBE3RR
# 55  TriC17_priB_B18AIDKO_LPS_emu         3             d3  ISCEgamma1+-5kb
# 54  TriC17_priB_B18AIDKO_LPS_emu         3             d3  ISCEgamma1+-5kb
# 53  TriC17_priB_B18AIDKO_LPS_emu         3             d3  ISCEgamma1+-5kb
# 52  TriC17_priB_B18AIDKO_LPS_emu         3             d3      ISCgG3+-3kb
# 51  TriC17_priB_B18AIDKO_LPS_emu         3             d3      ISCgG3+-3kb
# 50  TriC17_priB_B18AIDKO_LPS_emu         3             d3              mu+
# 49  TriC17_priB_B18AIDKO_LPS_emu         1             d0          3CBE3RR
# 48  TriC17_priB_B18AIDKO_LPS_emu         1             d0          3CBE3RR
# 47  TriC17_priB_B18AIDKO_LPS_emu         1             d0          3CBE3RR
# 46  TriC17_priB_B18AIDKO_LPS_emu         1             d0          3CBE3RR
# 45  TriC17_priB_B18AIDKO_LPS_emu         1             d0  ISCEgamma1+-5kb
# 44  TriC17_priB_B18AIDKO_LPS_emu         1             d0  ISCEgamma1+-5kb
# 43  TriC17_priB_B18AIDKO_LPS_emu         1             d0  ISCEgamma1+-5kb
# 42  TriC17_priB_B18AIDKO_LPS_emu         1             d0      ISCgG3+-3kb
# 41  TriC17_priB_B18AIDKO_LPS_emu         1             d0      ISCgG3+-3kb
# 40  TriC17_priB_B18AIDKO_LPS_emu         1             d0              mu+
# 39  TriC17_priB_B18AIDKO_LPS_emu         2             d0          3CBE3RR
# 38  TriC17_priB_B18AIDKO_LPS_emu         2             d0          3CBE3RR
# 37  TriC17_priB_B18AIDKO_LPS_emu         2             d0          3CBE3RR
# 36  TriC17_priB_B18AIDKO_LPS_emu         2             d0          3CBE3RR
# 35  TriC17_priB_B18AIDKO_LPS_emu         2             d0  ISCEgamma1+-5kb
# 34  TriC17_priB_B18AIDKO_LPS_emu         2             d0  ISCEgamma1+-5kb
# 33  TriC17_priB_B18AIDKO_LPS_emu         2             d0  ISCEgamma1+-5kb
# 32  TriC17_priB_B18AIDKO_LPS_emu         2             d0      ISCgG3+-3kb
# 31  TriC17_priB_B18AIDKO_LPS_emu         2             d0      ISCgG3+-3kb
# 30  TriC17_priB_B18AIDKO_LPS_emu         2             d0              mu+
# 29  TriC17_priB_B18AIDKO_LPS_emu         2             d3          3CBE3RR
# 28  TriC17_priB_B18AIDKO_LPS_emu         2             d3          3CBE3RR
# 27  TriC17_priB_B18AIDKO_LPS_emu         2             d3          3CBE3RR
# 26  TriC17_priB_B18AIDKO_LPS_emu         2             d3          3CBE3RR
# 25  TriC17_priB_B18AIDKO_LPS_emu         2             d3  ISCEgamma1+-5kb
# 24  TriC17_priB_B18AIDKO_LPS_emu         2             d3  ISCEgamma1+-5kb
# 23  TriC17_priB_B18AIDKO_LPS_emu         2             d3  ISCEgamma1+-5kb
# 22  TriC17_priB_B18AIDKO_LPS_emu         2             d3      ISCgG3+-3kb
# 21  TriC17_priB_B18AIDKO_LPS_emu         2             d3      ISCgG3+-3kb
# 20  TriC17_priB_B18AIDKO_LPS_emu         2             d3              mu+
# 19  TriC17_priB_B18AIDKO_LPS_emu         3             d0          3CBE3RR
# 18  TriC17_priB_B18AIDKO_LPS_emu         3             d0          3CBE3RR
# 17  TriC17_priB_B18AIDKO_LPS_emu         3             d0          3CBE3RR
# 16  TriC17_priB_B18AIDKO_LPS_emu         3             d0          3CBE3RR
# 15  TriC17_priB_B18AIDKO_LPS_emu         3             d0  ISCEgamma1+-5kb
# 14  TriC17_priB_B18AIDKO_LPS_emu         3             d0  ISCEgamma1+-5kb
# 13  TriC17_priB_B18AIDKO_LPS_emu         3             d0  ISCEgamma1+-5kb
# 12  TriC17_priB_B18AIDKO_LPS_emu         3             d0      ISCgG3+-3kb
# 11  TriC17_priB_B18AIDKO_LPS_emu         3             d0      ISCgG3+-3kb
# 10  TriC17_priB_B18AIDKO_LPS_emu         3             d0              mu+
# 9   TriC17_priB_B18AIDKO_LPS_emu         1             d3          3CBE3RR
# 8   TriC17_priB_B18AIDKO_LPS_emu         1             d3          3CBE3RR
# 7   TriC17_priB_B18AIDKO_LPS_emu         1             d3          3CBE3RR
# 6   TriC17_priB_B18AIDKO_LPS_emu         1             d3          3CBE3RR
# 5   TriC17_priB_B18AIDKO_LPS_emu         1             d3  ISCEgamma1+-5kb
# 4   TriC17_priB_B18AIDKO_LPS_emu         1             d3  ISCEgamma1+-5kb
# 3   TriC17_priB_B18AIDKO_LPS_emu         1             d3  ISCEgamma1+-5kb
# 2   TriC17_priB_B18AIDKO_LPS_emu         1             d3      ISCgG3+-3kb
# 1   TriC17_priB_B18AIDKO_LPS_emu         1             d3      ISCgG3+-3kb
# 0   TriC17_priB_B18AIDKO_LPS_emu         1             d3              mu+
#
#             region2  pinteractions                         regioncomb
# 59          3CBE3RR      33.886082                  3CBE3RR - 3CBE3RR
# 58  ISCEgamma1+-5kb       2.100971          3CBE3RR - ISCEgamma1+-5kb
# 57      ISCgG3+-3kb      11.194432              3CBE3RR - ISCgG3+-3kb
# 56              mu+      21.784103                      3CBE3RR - mu+
# 55  ISCEgamma1+-5kb      18.327449  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 54      ISCgG3+-3kb       2.391122      ISCEgamma1+-5kb - ISCgG3+-3kb
# 53              mu+       2.480685              ISCEgamma1+-5kb - mu+
# 52      ISCgG3+-3kb      50.363112          ISCgG3+-3kb - ISCgG3+-3kb
# 51              mu+      13.846071                  ISCgG3+-3kb - mu+
# 50              mu+     362.512778                          mu+ - mu+
# 49          3CBE3RR      21.375871                  3CBE3RR - 3CBE3RR
# 48  ISCEgamma1+-5kb       0.495797          3CBE3RR - ISCEgamma1+-5kb
# 47      ISCgG3+-3kb       4.218278              3CBE3RR - ISCgG3+-3kb
# 46              mu+       6.587799                      3CBE3RR - mu+
# 45  ISCEgamma1+-5kb      21.252819  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 44      ISCgG3+-3kb       2.168189      ISCEgamma1+-5kb - ISCgG3+-3kb
# 43              mu+       7.545893              ISCEgamma1+-5kb - mu+
# 42      ISCgG3+-3kb      54.139592          ISCgG3+-3kb - ISCgG3+-3kb
# 41              mu+      13.703452                  ISCgG3+-3kb - mu+
# 40              mu+     493.207708                          mu+ - mu+
# 39          3CBE3RR      27.459086                  3CBE3RR - 3CBE3RR
# 38  ISCEgamma1+-5kb       3.837921          3CBE3RR - ISCEgamma1+-5kb
# 37      ISCgG3+-3kb       1.900952              3CBE3RR - ISCgG3+-3kb
# 36              mu+      13.808974                      3CBE3RR - mu+
# 35  ISCEgamma1+-5kb      15.701735  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 34      ISCgG3+-3kb       4.360995      ISCEgamma1+-5kb - ISCgG3+-3kb
# 33              mu+       6.315565              ISCEgamma1+-5kb - mu+
# 32      ISCgG3+-3kb      52.103112          ISCgG3+-3kb - ISCgG3+-3kb
# 31              mu+      10.374464                  ISCgG3+-3kb - mu+
# 30              mu+     423.550000                          mu+ - mu+
# 29          3CBE3RR      35.999027                  3CBE3RR - 3CBE3RR
# 28  ISCEgamma1+-5kb       5.064615          3CBE3RR - ISCEgamma1+-5kb
# 27      ISCgG3+-3kb       5.900330              3CBE3RR - ISCgG3+-3kb
# 26              mu+      12.270470                      3CBE3RR - mu+
# 25  ISCEgamma1+-5kb      27.874796  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 24      ISCgG3+-3kb       5.969541      ISCEgamma1+-5kb - ISCgG3+-3kb
# 23              mu+       8.031012              ISCEgamma1+-5kb - mu+
# 22      ISCgG3+-3kb      53.835459          ISCgG3+-3kb - ISCgG3+-3kb
# 21              mu+       5.014643                  ISCgG3+-3kb - mu+
# 20              mu+     414.282361                          mu+ - mu+
# 19          3CBE3RR      23.853419                  3CBE3RR - 3CBE3RR
# 18  ISCEgamma1+-5kb       5.207353          3CBE3RR - ISCEgamma1+-5kb
# 17      ISCgG3+-3kb       4.576410              3CBE3RR - ISCgG3+-3kb
# 16              mu+       8.721560                      3CBE3RR - mu+
# 15  ISCEgamma1+-5kb      18.663163  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 14      ISCgG3+-3kb       4.711786      ISCEgamma1+-5kb - ISCgG3+-3kb
# 13              mu+       4.804196              ISCEgamma1+-5kb - mu+
# 12      ISCgG3+-3kb      51.193724          ISCgG3+-3kb - ISCgG3+-3kb
# 11              mu+       4.756607                  ISCgG3+-3kb - mu+
# 10              mu+     484.109167                          mu+ - mu+
# 9           3CBE3RR      30.752498                  3CBE3RR - 3CBE3RR
# 8   ISCEgamma1+-5kb       3.476694          3CBE3RR - ISCEgamma1+-5kb
# 7       ISCgG3+-3kb       1.964286              3CBE3RR - ISCgG3+-3kb
# 6               mu+      12.453868                      3CBE3RR - mu+
# 5   ISCEgamma1+-5kb      21.695765  ISCEgamma1+-5kb - ISCEgamma1+-5kb
# 4       ISCgG3+-3kb       1.411224      ISCEgamma1+-5kb - ISCgG3+-3kb
# 3               mu+       0.823214              ISCEgamma1+-5kb - mu+
# 2       ISCgG3+-3kb      84.733776          ISCgG3+-3kb - ISCgG3+-3kb
# 1               mu+       2.893750                  ISCgG3+-3kb - mu+
# 0               mu+     414.257569                          mu+ - mu+

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5
axCounter = 1
for (region1, group) in contactsums.groupby('region1'): # for each subplot / region1
	# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
	ax = fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), sharey = ax) if axCounter > 1 else fig.add_subplot(int(str(1) + str(len(set(contactsums.region2))) + str(axCounter)), yscale = 'log')
	axCounter = axCounter + 1
	sns.barplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
		errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax)
	sns.stripplot(data=group, x='region2', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
		palette=['black', 'red'])

	boxlist = [] # list with pairs for statistical significance test
	for reg in group['region2'].unique():
		boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
	statannot.add_stat_annotation(ax, data=group, x='region2', y='pinteractions', hue='treatment_time', 
		box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2, line_offset=0.3, line_offset_to_box=0.2)
	
	handles, labels = ax.get_legend_handles_labels()
	# ax.legend_.remove()
	# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
	ax.set_ylabel('log(Interactions norm. by N of bins)')
	ax.set_xlabel("x regions")
	ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
	ax.set_title(f'Emu_capture -- {region1} -- x')
fig.suptitle('TriC17_mm9AIDKO-LPS Emu interactions')

# fig.savefig('../plots/TriC17/TriC17_mm9AIDKO-LPS_RegOfInterest_EmuCap_allZones.pdf')
# Out:
# ISCEgamma1+-5kb_d3 v.s. ISCEgamma1+-5kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=2.238e-01
# 3CBE3RR_d3 v.s. 3CBE3RR_d0: t-test independent samples with Bonferroni correction, P_val=6.486e-02 stat=3.994e+00
# ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=9.948e-01
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=8.081e-01 stat=1.525e+00
# ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-3.065e-01
# ISCEgamma1+-5kb_d3 v.s. ISCEgamma1+-5kb_d0: t-test independent samples with Bonferroni correction, P_val=8.187e-01 stat=1.270e+00
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.054e+00
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-5.553e-01
# ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=7.846e-01 stat=9.580e-01
# mu+_d3 v.s. mu+_d0: t-test independent samples with Bonferroni correction, P_val=6.596e-02 stat=-2.511e+00
# Text(0.5, 0.98, 'TriC17_mm9AIDKO-LPS Emu interactions')

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5

region_order = ['mu+ - mu+', 'ISCgG3+-3kb - mu+', 'ISCEgamma1+-5kb - mu+', '3CBE3RR - mu+', 'ISCgG3+-3kb - ISCgG3+-3kb', 'ISCEgamma1+-5kb - ISCgG3+-3kb', '3CBE3RR - ISCgG3+-3kb', 'ISCEgamma1+-5kb - ISCEgamma1+-5kb', '3CBE3RR - ISCEgamma1+-5kb', '3CBE3RR - 3CBE3RR']

fig = plt.figure(figsize=(30,10))

# maxInteraction = max(contactsums['pinteractions'])
# maxInteraction = maxInteraction + maxInteraction/10

ymax = max(contactsums['pinteractions']) +0.5

# ax = fig.add_subplot(1, len(set(contactsums.region1)), axCounter)
ax = fig.add_subplot(111, yscale = 'log')
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, order=region_order, ax=ax, bottom=0.001)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	order=region_order, palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2)


handles, labels = ax.get_legend_handles_labels()
# ax.legend_.remove()
# ax.legend(handles, ['Spt5 deprived', 'ctrl'])
ax.set_ylabel('log(Interactions norm. by N of bins)')
ax.set_xlabel("x regions")
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
ax.set_title(f'Emu_capture -- x')
fig.suptitle('TriC17_mm9AIDKO-LPS Emu interactions')
ax.set_ylim(0.5)

fig.savefig('../plots/TriC17/TriC17_mm9AIDKO-LPS_RegOfInterest_EmuCap_allZones_combined.pdf')
# Out:
# 3CBE3RR - 3CBE3RR_d3 v.s. 3CBE3RR - 3CBE3RR_d0: t-test independent samples with Bonferroni correction, P_val=1.622e-01 stat=3.994e+00
# 3CBE3RR - ISCEgamma1+-5kb_d3 v.s. 3CBE3RR - ISCEgamma1+-5kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=2.238e-01
# ISCgG3+-3kb - mu+_d3 v.s. ISCgG3+-3kb - mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-5.553e-01
# mu+ - mu+_d3 v.s. mu+ - mu+_d0: t-test independent samples with Bonferroni correction, P_val=6.596e-01 stat=-2.511e+00
# ISCEgamma1+-5kb - mu+_d3 v.s. ISCEgamma1+-5kb - mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-1.054e+00
# 3CBE3RR - ISCgG3+-3kb_d3 v.s. 3CBE3RR - ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=9.948e-01
# 3CBE3RR - mu+_d3 v.s. 3CBE3RR - mu+_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.525e+00
# ISCEgamma1+-5kb - ISCEgamma1+-5kb_d3 v.s. ISCEgamma1+-5kb - ISCEgamma1+-5kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=1.270e+00
# ISCEgamma1+-5kb - ISCgG3+-3kb_d3 v.s. ISCEgamma1+-5kb - ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=-3.065e-01
# ISCgG3+-3kb - ISCgG3+-3kb_d3 v.s. ISCgG3+-3kb - ISCgG3+-3kb_d0: t-test independent samples with Bonferroni correction, P_val=1.000e+00 stat=9.580e-01
