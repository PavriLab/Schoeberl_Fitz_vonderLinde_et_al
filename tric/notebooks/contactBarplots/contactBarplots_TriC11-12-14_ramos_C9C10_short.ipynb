# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.colors as clr
import matplotlib.patches as patches
from matplotlib.lines import Line2D
import matplotlib as mpl
import itertools as it
import argparse as ap
import statannot 
from statannotations.Annotator import Annotator

pd.set_option('display.max_rows', 100)

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC14.tsv' -r '../resource/regions_of_interest_Ramos.tsv' \
	-r1 '3RRCBE2' '3RRCBE1' 'mu-4kb' -r2 '3RRCBE1' 'Ed+-2kb' 'mu-4kb' \
	--prefix 'TriC14_lane_1_Ramos_C' --dir '../TriCplots/TriC14_mapq30' --capture '5Smu_capture' \
	--genome 'hg38' --igh 105550000 105866000 --selfInt
contactsums1 = contactsums
contactsums1
# Out:
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                      sample  replicate  treatment_time  region1  region2  \
# 0    TriC14_lane_1_Ramos_C9          1               0  3RRCBE2  3RRCBE1
# 1    TriC14_lane_1_Ramos_C9          1               0  3RRCBE2  Ed+-2kb
# 2    TriC14_lane_1_Ramos_C9          1               0  3RRCBE2   mu-4kb
# 3    TriC14_lane_1_Ramos_C9          1               0  3RRCBE1  3RRCBE1
# 4    TriC14_lane_1_Ramos_C9          1               0  3RRCBE1  Ed+-2kb
# 5    TriC14_lane_1_Ramos_C9          1               0  3RRCBE1   mu-4kb
# 6    TriC14_lane_1_Ramos_C9          1               0   mu-4kb   mu-4kb
# 7    TriC14_lane_1_Ramos_C9          2               0  3RRCBE2  3RRCBE1
# 8    TriC14_lane_1_Ramos_C9          2               0  3RRCBE2  Ed+-2kb
# 9    TriC14_lane_1_Ramos_C9          2               0  3RRCBE2   mu-4kb
# 10   TriC14_lane_1_Ramos_C9          2               0  3RRCBE1  3RRCBE1
# 11   TriC14_lane_1_Ramos_C9          2               0  3RRCBE1  Ed+-2kb
# 12   TriC14_lane_1_Ramos_C9          2               0  3RRCBE1   mu-4kb
# 13   TriC14_lane_1_Ramos_C9          2               0   mu-4kb   mu-4kb
# 14  TriC14_lane_1_Ramos_C10          1               0  3RRCBE2  3RRCBE1
# 15  TriC14_lane_1_Ramos_C10          1               0  3RRCBE2  Ed+-2kb
# 16  TriC14_lane_1_Ramos_C10          1               0  3RRCBE2   mu-4kb
# 17  TriC14_lane_1_Ramos_C10          1               0  3RRCBE1  3RRCBE1
# 18  TriC14_lane_1_Ramos_C10          1               0  3RRCBE1  Ed+-2kb
# 19  TriC14_lane_1_Ramos_C10          1               0  3RRCBE1   mu-4kb
# 20  TriC14_lane_1_Ramos_C10          1               0   mu-4kb   mu-4kb
# 21  TriC14_lane_1_Ramos_C10          2               0  3RRCBE2  3RRCBE1
# 22  TriC14_lane_1_Ramos_C10          2               0  3RRCBE2  Ed+-2kb
# 23  TriC14_lane_1_Ramos_C10          2               0  3RRCBE2   mu-4kb
# 24  TriC14_lane_1_Ramos_C10          2               0  3RRCBE1  3RRCBE1
# 25  TriC14_lane_1_Ramos_C10          2               0  3RRCBE1  Ed+-2kb
# 26  TriC14_lane_1_Ramos_C10          2               0  3RRCBE1   mu-4kb
# 27  TriC14_lane_1_Ramos_C10          2               0   mu-4kb   mu-4kb
# 28   TriC14_lane_1_Ramos_C9          1               8  3RRCBE2  3RRCBE1
# 29   TriC14_lane_1_Ramos_C9          1               8  3RRCBE2  Ed+-2kb
# 30   TriC14_lane_1_Ramos_C9          1               8  3RRCBE2   mu-4kb
# 31   TriC14_lane_1_Ramos_C9          1               8  3RRCBE1  3RRCBE1
# 32   TriC14_lane_1_Ramos_C9          1               8  3RRCBE1  Ed+-2kb
# 33   TriC14_lane_1_Ramos_C9          1               8  3RRCBE1   mu-4kb
# 34   TriC14_lane_1_Ramos_C9          1               8   mu-4kb   mu-4kb
# 35   TriC14_lane_1_Ramos_C9          2               8  3RRCBE2  3RRCBE1
# 36   TriC14_lane_1_Ramos_C9          2               8  3RRCBE2  Ed+-2kb
# 37   TriC14_lane_1_Ramos_C9          2               8  3RRCBE2   mu-4kb
# 38   TriC14_lane_1_Ramos_C9          2               8  3RRCBE1  3RRCBE1
# 39   TriC14_lane_1_Ramos_C9          2               8  3RRCBE1  Ed+-2kb
# 40   TriC14_lane_1_Ramos_C9          2               8  3RRCBE1   mu-4kb
# 41   TriC14_lane_1_Ramos_C9          2               8   mu-4kb   mu-4kb
# 42  TriC14_lane_1_Ramos_C10          1               8  3RRCBE2  3RRCBE1
# 43  TriC14_lane_1_Ramos_C10          1               8  3RRCBE2  Ed+-2kb
# 44  TriC14_lane_1_Ramos_C10          1               8  3RRCBE2   mu-4kb
# 45  TriC14_lane_1_Ramos_C10          1               8  3RRCBE1  3RRCBE1
# 46  TriC14_lane_1_Ramos_C10          1               8  3RRCBE1  Ed+-2kb
# 47  TriC14_lane_1_Ramos_C10          1               8  3RRCBE1   mu-4kb
# 48  TriC14_lane_1_Ramos_C10          1               8   mu-4kb   mu-4kb
# 49  TriC14_lane_1_Ramos_C10          2               8  3RRCBE2  3RRCBE1
# 50  TriC14_lane_1_Ramos_C10          2               8  3RRCBE2  Ed+-2kb
# 51  TriC14_lane_1_Ramos_C10          2               8  3RRCBE2   mu-4kb
# 52  TriC14_lane_1_Ramos_C10          2               8  3RRCBE1  3RRCBE1
# 53  TriC14_lane_1_Ramos_C10          2               8  3RRCBE1  Ed+-2kb
# 54  TriC14_lane_1_Ramos_C10          2               8  3RRCBE1   mu-4kb
# 55  TriC14_lane_1_Ramos_C10          2               8   mu-4kb   mu-4kb
# 56   TriC14_lane_1_Ramos_C9          1              12  3RRCBE2  3RRCBE1
# 57   TriC14_lane_1_Ramos_C9          1              12  3RRCBE2  Ed+-2kb
# 58   TriC14_lane_1_Ramos_C9          1              12  3RRCBE2   mu-4kb
# 59   TriC14_lane_1_Ramos_C9          1              12  3RRCBE1  3RRCBE1
# 60   TriC14_lane_1_Ramos_C9          1              12  3RRCBE1  Ed+-2kb
# 61   TriC14_lane_1_Ramos_C9          1              12  3RRCBE1   mu-4kb
# 62   TriC14_lane_1_Ramos_C9          1              12   mu-4kb   mu-4kb
# 63   TriC14_lane_1_Ramos_C9          2              12  3RRCBE2  3RRCBE1
# 64   TriC14_lane_1_Ramos_C9          2              12  3RRCBE2  Ed+-2kb
# 65   TriC14_lane_1_Ramos_C9          2              12  3RRCBE2   mu-4kb
# 66   TriC14_lane_1_Ramos_C9          2              12  3RRCBE1  3RRCBE1
# 67   TriC14_lane_1_Ramos_C9          2              12  3RRCBE1  Ed+-2kb
# 68   TriC14_lane_1_Ramos_C9          2              12  3RRCBE1   mu-4kb
# 69   TriC14_lane_1_Ramos_C9          2              12   mu-4kb   mu-4kb
# 70  TriC14_lane_1_Ramos_C10          1              12  3RRCBE2  3RRCBE1
# 71  TriC14_lane_1_Ramos_C10          1              12  3RRCBE2  Ed+-2kb
# 72  TriC14_lane_1_Ramos_C10          1              12  3RRCBE2   mu-4kb
# 73  TriC14_lane_1_Ramos_C10          1              12  3RRCBE1  3RRCBE1
# 74  TriC14_lane_1_Ramos_C10          1              12  3RRCBE1  Ed+-2kb
# 75  TriC14_lane_1_Ramos_C10          1              12  3RRCBE1   mu-4kb
# 76  TriC14_lane_1_Ramos_C10          1              12   mu-4kb   mu-4kb
# 77  TriC14_lane_1_Ramos_C10          2              12  3RRCBE2  3RRCBE1
# 78  TriC14_lane_1_Ramos_C10          2              12  3RRCBE2  Ed+-2kb
# 79  TriC14_lane_1_Ramos_C10          2              12  3RRCBE2   mu-4kb
# 80  TriC14_lane_1_Ramos_C10          2              12  3RRCBE1  3RRCBE1
# 81  TriC14_lane_1_Ramos_C10          2              12  3RRCBE1  Ed+-2kb
# 82  TriC14_lane_1_Ramos_C10          2              12  3RRCBE1   mu-4kb
# 83  TriC14_lane_1_Ramos_C10          2              12   mu-4kb   mu-4kb
#
#     pinteractions         regioncomb
# 0       46.745467  3RRCBE2 - 3RRCBE1
# 1       15.387333  3RRCBE2 - Ed+-2kb
# 2        3.379222   3RRCBE2 - mu-4kb
# 3       71.108311  3RRCBE1 - 3RRCBE1
# 4       24.441200  3RRCBE1 - Ed+-2kb
# 5        8.250222   3RRCBE1 - mu-4kb
# 6     1347.305000    mu-4kb - mu-4kb
# 7       36.904311  3RRCBE2 - 3RRCBE1
# 8        2.572400  3RRCBE2 - Ed+-2kb
# 9        4.676000   3RRCBE2 - mu-4kb
# 10      89.238178  3RRCBE1 - 3RRCBE1
# 11      10.718133  3RRCBE1 - Ed+-2kb
# 12       8.711111   3RRCBE1 - mu-4kb
# 13    1879.851389    mu-4kb - mu-4kb
# 14      61.978400  3RRCBE2 - 3RRCBE1
# 15       2.689600  3RRCBE2 - Ed+-2kb
# 16      11.685556   3RRCBE2 - mu-4kb
# 17      82.429022  3RRCBE1 - 3RRCBE1
# 18      13.547067  3RRCBE1 - Ed+-2kb
# 19      31.987222   3RRCBE1 - mu-4kb
# 20    1697.675833    mu-4kb - mu-4kb
# 21      50.445067  3RRCBE2 - 3RRCBE1
# 22       5.035600  3RRCBE2 - Ed+-2kb
# 23      16.934889   3RRCBE2 - mu-4kb
# 24     130.476533  3RRCBE1 - 3RRCBE1
# 25       2.288267  3RRCBE1 - Ed+-2kb
# 26      34.071000   3RRCBE1 - mu-4kb
# 27    2055.223333    mu-4kb - mu-4kb
# 28      54.500044  3RRCBE2 - 3RRCBE1
# 29       6.002000  3RRCBE2 - Ed+-2kb
# 30      18.614556   3RRCBE2 - mu-4kb
# 31      83.283067  3RRCBE1 - 3RRCBE1
# 32      10.733600  3RRCBE1 - Ed+-2kb
# 33      11.303222   3RRCBE1 - mu-4kb
# 34    1964.358333    mu-4kb - mu-4kb
# 35      50.449422  3RRCBE2 - 3RRCBE1
# 36       7.311467  3RRCBE2 - Ed+-2kb
# 37      33.093667   3RRCBE2 - mu-4kb
# 38      65.831333  3RRCBE1 - 3RRCBE1
# 39      12.562800  3RRCBE1 - Ed+-2kb
# 40      15.056889   3RRCBE1 - mu-4kb
# 41    1809.891389    mu-4kb - mu-4kb
# 42      91.924000  3RRCBE2 - 3RRCBE1
# 43       7.126667  3RRCBE2 - Ed+-2kb
# 44       5.953667   3RRCBE2 - mu-4kb
# 45      71.819867  3RRCBE1 - 3RRCBE1
# 46       9.768800  3RRCBE1 - Ed+-2kb
# 47      19.392444   3RRCBE1 - mu-4kb
# 48    1366.370833    mu-4kb - mu-4kb
# 49      29.629200  3RRCBE2 - 3RRCBE1
# 50      10.047467  3RRCBE2 - Ed+-2kb
# 51       9.127667   3RRCBE2 - mu-4kb
# 52     115.532089  3RRCBE1 - 3RRCBE1
# 53      13.644533  3RRCBE1 - Ed+-2kb
# 54      18.509667   3RRCBE1 - mu-4kb
# 55    1374.561944    mu-4kb - mu-4kb
# 56      60.249200  3RRCBE2 - 3RRCBE1
# 57       3.152133  3RRCBE2 - Ed+-2kb
# 58       6.567000   3RRCBE2 - mu-4kb
# 59      63.845378  3RRCBE1 - 3RRCBE1
# 60       6.566933  3RRCBE1 - Ed+-2kb
# 61       6.567000   3RRCBE1 - mu-4kb
# 62    1552.081944    mu-4kb - mu-4kb
# 63      73.117200  3RRCBE2 - 3RRCBE1
# 64      15.497733  3RRCBE2 - Ed+-2kb
# 65       0.620889   3RRCBE2 - mu-4kb
# 66      44.903422  3RRCBE1 - 3RRCBE1
# 67      14.520667  3RRCBE1 - Ed+-2kb
# 68       0.525889   3RRCBE1 - mu-4kb
# 69    1373.101111    mu-4kb - mu-4kb
# 70      54.759867  3RRCBE2 - 3RRCBE1
# 71       6.186667  3RRCBE2 - Ed+-2kb
# 72       0.663667   3RRCBE2 - mu-4kb
# 73      65.792178  3RRCBE1 - 3RRCBE1
# 74      11.094667  3RRCBE1 - Ed+-2kb
# 75      16.879778   3RRCBE1 - mu-4kb
# 76    1526.309722    mu-4kb - mu-4kb
# 77      18.516578  3RRCBE2 - 3RRCBE1
# 78       3.942133  3RRCBE2 - Ed+-2kb
# 79       3.942000   3RRCBE2 - mu-4kb
# 80     110.358400  3RRCBE1 - 3RRCBE1
# 81      50.621067  3RRCBE1 - Ed+-2kb
# 82      69.218556   3RRCBE1 - mu-4kb
# 83    1173.156389    mu-4kb - mu-4kb

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC12_renamed.tsv' -r '../resource/regions_of_interest_Ramos.tsv' \
	-r1 '3RRCBE2' '3RRCBE1' 'mu-4kb' -r2 '3RRCBE1' 'Ed+-2kb' 'mu-4kb' \
	--prefix 'TriC12_lane_1_Ramos2_C9' --dir '../TriCplots/TriC12_mapq30/' --capture '5Smu_capture' \
	--genome 'hg38' --igh 105550000 105866000 --selfInt
contactsums2 = contactsums
contactsums2
# Out:
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                      sample  replicate  treatment_time  region1  region2  \
# 0   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE2  3RRCBE1
# 1   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE2  Ed+-2kb
# 2   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE2   mu-4kb
# 3   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE1  3RRCBE1
# 4   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE1  Ed+-2kb
# 5   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE1   mu-4kb
# 6   TriC12_lane_1_Ramos2_C9          1               0   mu-4kb   mu-4kb
# 7   TriC12_lane_1_Ramos2_C9          1               4  3RRCBE2  3RRCBE1
# 8   TriC12_lane_1_Ramos2_C9          1               4  3RRCBE2  Ed+-2kb
# 9   TriC12_lane_1_Ramos2_C9          1               4  3RRCBE2   mu-4kb
# 10  TriC12_lane_1_Ramos2_C9          1               4  3RRCBE1  3RRCBE1
# 11  TriC12_lane_1_Ramos2_C9          1               4  3RRCBE1  Ed+-2kb
# 12  TriC12_lane_1_Ramos2_C9          1               4  3RRCBE1   mu-4kb
# 13  TriC12_lane_1_Ramos2_C9          1               4   mu-4kb   mu-4kb
# 14  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE2  3RRCBE1
# 15  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE2  Ed+-2kb
# 16  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE2   mu-4kb
# 17  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE1  3RRCBE1
# 18  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE1  Ed+-2kb
# 19  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE1   mu-4kb
# 20  TriC12_lane_1_Ramos2_C9          1               8   mu-4kb   mu-4kb
# 21  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE2  3RRCBE1
# 22  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE2  Ed+-2kb
# 23  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE2   mu-4kb
# 24  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE1  3RRCBE1
# 25  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE1  Ed+-2kb
# 26  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE1   mu-4kb
# 27  TriC12_lane_1_Ramos2_C9          2               0   mu-4kb   mu-4kb
# 28  TriC12_lane_1_Ramos2_C9          2               4  3RRCBE2  3RRCBE1
# 29  TriC12_lane_1_Ramos2_C9          2               4  3RRCBE2  Ed+-2kb
# 30  TriC12_lane_1_Ramos2_C9          2               4  3RRCBE2   mu-4kb
# 31  TriC12_lane_1_Ramos2_C9          2               4  3RRCBE1  3RRCBE1
# 32  TriC12_lane_1_Ramos2_C9          2               4  3RRCBE1  Ed+-2kb
# 33  TriC12_lane_1_Ramos2_C9          2               4  3RRCBE1   mu-4kb
# 34  TriC12_lane_1_Ramos2_C9          2               4   mu-4kb   mu-4kb
# 35  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE2  3RRCBE1
# 36  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE2  Ed+-2kb
# 37  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE2   mu-4kb
# 38  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE1  3RRCBE1
# 39  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE1  Ed+-2kb
# 40  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE1   mu-4kb
# 41  TriC12_lane_1_Ramos2_C9          2               8   mu-4kb   mu-4kb
#
#     pinteractions         regioncomb
# 0       24.912711  3RRCBE2 - 3RRCBE1
# 1        5.493733  3RRCBE2 - Ed+-2kb
# 2       20.635333   3RRCBE2 - mu-4kb
# 3       81.657689  3RRCBE1 - 3RRCBE1
# 4        9.265333  3RRCBE1 - Ed+-2kb
# 5       27.597222   3RRCBE1 - mu-4kb
# 6     2055.107222    mu-4kb - mu-4kb
# 7       10.281333  3RRCBE2 - 3RRCBE1
# 8       16.974800  3RRCBE2 - Ed+-2kb
# 9        7.928556   3RRCBE2 - mu-4kb
# 10     108.661733  3RRCBE1 - 3RRCBE1
# 11       5.015333  3RRCBE1 - Ed+-2kb
# 12       6.269222   3RRCBE1 - mu-4kb
# 13    2130.676111    mu-4kb - mu-4kb
# 14      49.203200  3RRCBE2 - 3RRCBE1
# 15       0.000000  3RRCBE2 - Ed+-2kb
# 16      16.864000   3RRCBE2 - mu-4kb
# 17      87.449733  3RRCBE1 - 3RRCBE1
# 18       1.506933  3RRCBE1 - Ed+-2kb
# 19      23.127778   3RRCBE1 - mu-4kb
# 20    1816.197778    mu-4kb - mu-4kb
# 21      65.518667  3RRCBE2 - 3RRCBE1
# 22       4.594800  3RRCBE2 - Ed+-2kb
# 23      14.766667   3RRCBE2 - mu-4kb
# 24     105.124133  3RRCBE1 - 3RRCBE1
# 25       0.633733  3RRCBE1 - Ed+-2kb
# 26      39.417222   3RRCBE1 - mu-4kb
# 27    2440.704167    mu-4kb - mu-4kb
# 28      45.590978  3RRCBE2 - 3RRCBE1
# 29       9.729600  3RRCBE2 - Ed+-2kb
# 30      28.821556   3RRCBE2 - mu-4kb
# 31     107.122978  3RRCBE1 - 3RRCBE1
# 32      12.078400  3RRCBE1 - Ed+-2kb
# 33       4.475889   3RRCBE1 - mu-4kb
# 34    2010.673056    mu-4kb - mu-4kb
# 35      36.563911  3RRCBE2 - 3RRCBE1
# 36      21.290000  3RRCBE2 - Ed+-2kb
# 37      21.905333   3RRCBE2 - mu-4kb
# 38      73.978222  3RRCBE1 - 3RRCBE1
# 39       3.887200  3RRCBE1 - Ed+-2kb
# 40      77.029444   3RRCBE1 - mu-4kb
# 41    1521.927778    mu-4kb - mu-4kb

# %%
# %run contactBarplots_functions.py -i '../resource/sampleinfo_TriC_11.tsv' -r '../resource/regions_of_interest_Ramos.tsv' \
	-r1 '3RRCBE2' '3RRCBE1' 'mu-4kb' -r2 '3RRCBE1' 'Ed+-2kb' 'mu-4kb' \
	--prefix 'TriC_11_lane_1_Ramos_C9_0h_' --dir '../TriCplots/TriC11_mapq30/' --capture '5Smu_capture' \
	--genome 'hg38' --igh 105550000 105866000 --selfInt
contactsums3 = contactsums
contactsums3
# Out:
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 3RRCBE1 was not included because it is in wrong order. Please switch their places if the interaction should be included.
# The interaction of region1 mu-4kb with region2 Ed+-2kb was not included because it is in wrong order. Please switch their places if the interaction should be included.
#                      sample  replicate  treatment_time  region1  region2  \
# 0   TriC_11_lane_1_Ramos_C9          1               0  3RRCBE2  3RRCBE1
# 1   TriC_11_lane_1_Ramos_C9          1               0  3RRCBE2  Ed+-2kb
# 2   TriC_11_lane_1_Ramos_C9          1               0  3RRCBE2   mu-4kb
# 3   TriC_11_lane_1_Ramos_C9          1               0  3RRCBE1  3RRCBE1
# 4   TriC_11_lane_1_Ramos_C9          1               0  3RRCBE1  Ed+-2kb
# 5   TriC_11_lane_1_Ramos_C9          1               0  3RRCBE1   mu-4kb
# 6   TriC_11_lane_1_Ramos_C9          1               0   mu-4kb   mu-4kb
# 7   TriC_11_lane_1_Ramos_C9          2               0  3RRCBE2  3RRCBE1
# 8   TriC_11_lane_1_Ramos_C9          2               0  3RRCBE2  Ed+-2kb
# 9   TriC_11_lane_1_Ramos_C9          2               0  3RRCBE2   mu-4kb
# 10  TriC_11_lane_1_Ramos_C9          2               0  3RRCBE1  3RRCBE1
# 11  TriC_11_lane_1_Ramos_C9          2               0  3RRCBE1  Ed+-2kb
# 12  TriC_11_lane_1_Ramos_C9          2               0  3RRCBE1   mu-4kb
# 13  TriC_11_lane_1_Ramos_C9          2               0   mu-4kb   mu-4kb
#
#     pinteractions         regioncomb
# 0       22.958622  3RRCBE2 - 3RRCBE1
# 1        1.265467  3RRCBE2 - Ed+-2kb
# 2        4.798000   3RRCBE2 - mu-4kb
# 3       75.824133  3RRCBE1 - 3RRCBE1
# 4       10.099867  3RRCBE1 - Ed+-2kb
# 5       19.117111   3RRCBE1 - mu-4kb
# 6     2117.736944    mu-4kb - mu-4kb
# 7       18.065733  3RRCBE2 - 3RRCBE1
# 8        0.901600  3RRCBE2 - Ed+-2kb
# 9       28.735444   3RRCBE2 - mu-4kb
# 10      71.257956  3RRCBE1 - 3RRCBE1
# 11       6.471867  3RRCBE1 - Ed+-2kb
# 12       9.488556   3RRCBE1 - mu-4kb
# 13    2310.087500    mu-4kb - mu-4kb

# %%
region_order = ['3RRCBE1 - mu-4kb', '3RRCBE2 - mu-4kb', '3RRCBE1 - Ed+-2kb', '3RRCBE2 - Ed+-2kb', '3RRCBE2 - 3RRCBE1']

contactsums = pd.concat([contactsums1, contactsums2])
contactsums = contactsums.loc[contactsums['treatment_time'].isin([0, 8])] # select only ctrls and 8h treatment
contactsumsSelf = contactsums.loc[contactsums['regioncomb'] == 'mu-4kb - mu-4kb'] # isolate zone 1
contactsums = contactsums.loc[contactsums['regioncomb'].isin(region_order)] # remove any self interaction zones
contactsums =  contactsums.sort_values(['treatment_time', 'sample'])
contactsums
# Out:
#                      sample  replicate  treatment_time  region1  region2  \
# 0   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE2  3RRCBE1
# 1   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE2  Ed+-2kb
# 2   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE2   mu-4kb
# 4   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE1  Ed+-2kb
# 5   TriC12_lane_1_Ramos2_C9          1               0  3RRCBE1   mu-4kb
# 21  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE2  3RRCBE1
# 22  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE2  Ed+-2kb
# 23  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE2   mu-4kb
# 25  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE1  Ed+-2kb
# 26  TriC12_lane_1_Ramos2_C9          2               0  3RRCBE1   mu-4kb
# 14  TriC14_lane_1_Ramos_C10          1               0  3RRCBE2  3RRCBE1
# 15  TriC14_lane_1_Ramos_C10          1               0  3RRCBE2  Ed+-2kb
# 16  TriC14_lane_1_Ramos_C10          1               0  3RRCBE2   mu-4kb
# 18  TriC14_lane_1_Ramos_C10          1               0  3RRCBE1  Ed+-2kb
# 19  TriC14_lane_1_Ramos_C10          1               0  3RRCBE1   mu-4kb
# 21  TriC14_lane_1_Ramos_C10          2               0  3RRCBE2  3RRCBE1
# 22  TriC14_lane_1_Ramos_C10          2               0  3RRCBE2  Ed+-2kb
# 23  TriC14_lane_1_Ramos_C10          2               0  3RRCBE2   mu-4kb
# 25  TriC14_lane_1_Ramos_C10          2               0  3RRCBE1  Ed+-2kb
# 26  TriC14_lane_1_Ramos_C10          2               0  3RRCBE1   mu-4kb
# 0    TriC14_lane_1_Ramos_C9          1               0  3RRCBE2  3RRCBE1
# 1    TriC14_lane_1_Ramos_C9          1               0  3RRCBE2  Ed+-2kb
# 2    TriC14_lane_1_Ramos_C9          1               0  3RRCBE2   mu-4kb
# 4    TriC14_lane_1_Ramos_C9          1               0  3RRCBE1  Ed+-2kb
# 5    TriC14_lane_1_Ramos_C9          1               0  3RRCBE1   mu-4kb
# 7    TriC14_lane_1_Ramos_C9          2               0  3RRCBE2  3RRCBE1
# 8    TriC14_lane_1_Ramos_C9          2               0  3RRCBE2  Ed+-2kb
# 9    TriC14_lane_1_Ramos_C9          2               0  3RRCBE2   mu-4kb
# 11   TriC14_lane_1_Ramos_C9          2               0  3RRCBE1  Ed+-2kb
# 12   TriC14_lane_1_Ramos_C9          2               0  3RRCBE1   mu-4kb
# 14  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE2  3RRCBE1
# 15  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE2  Ed+-2kb
# 16  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE2   mu-4kb
# 18  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE1  Ed+-2kb
# 19  TriC12_lane_1_Ramos2_C9          1               8  3RRCBE1   mu-4kb
# 35  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE2  3RRCBE1
# 36  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE2  Ed+-2kb
# 37  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE2   mu-4kb
# 39  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE1  Ed+-2kb
# 40  TriC12_lane_1_Ramos2_C9          2               8  3RRCBE1   mu-4kb
# 42  TriC14_lane_1_Ramos_C10          1               8  3RRCBE2  3RRCBE1
# 43  TriC14_lane_1_Ramos_C10          1               8  3RRCBE2  Ed+-2kb
# 44  TriC14_lane_1_Ramos_C10          1               8  3RRCBE2   mu-4kb
# 46  TriC14_lane_1_Ramos_C10          1               8  3RRCBE1  Ed+-2kb
# 47  TriC14_lane_1_Ramos_C10          1               8  3RRCBE1   mu-4kb
# 49  TriC14_lane_1_Ramos_C10          2               8  3RRCBE2  3RRCBE1
# 50  TriC14_lane_1_Ramos_C10          2               8  3RRCBE2  Ed+-2kb
# 51  TriC14_lane_1_Ramos_C10          2               8  3RRCBE2   mu-4kb
# 53  TriC14_lane_1_Ramos_C10          2               8  3RRCBE1  Ed+-2kb
# 54  TriC14_lane_1_Ramos_C10          2               8  3RRCBE1   mu-4kb
# 28   TriC14_lane_1_Ramos_C9          1               8  3RRCBE2  3RRCBE1
# 29   TriC14_lane_1_Ramos_C9          1               8  3RRCBE2  Ed+-2kb
# 30   TriC14_lane_1_Ramos_C9          1               8  3RRCBE2   mu-4kb
# 32   TriC14_lane_1_Ramos_C9          1               8  3RRCBE1  Ed+-2kb
# 33   TriC14_lane_1_Ramos_C9          1               8  3RRCBE1   mu-4kb
# 35   TriC14_lane_1_Ramos_C9          2               8  3RRCBE2  3RRCBE1
# 36   TriC14_lane_1_Ramos_C9          2               8  3RRCBE2  Ed+-2kb
# 37   TriC14_lane_1_Ramos_C9          2               8  3RRCBE2   mu-4kb
# 39   TriC14_lane_1_Ramos_C9          2               8  3RRCBE1  Ed+-2kb
# 40   TriC14_lane_1_Ramos_C9          2               8  3RRCBE1   mu-4kb
#
#     pinteractions         regioncomb
# 0       24.912711  3RRCBE2 - 3RRCBE1
# 1        5.493733  3RRCBE2 - Ed+-2kb
# 2       20.635333   3RRCBE2 - mu-4kb
# 4        9.265333  3RRCBE1 - Ed+-2kb
# 5       27.597222   3RRCBE1 - mu-4kb
# 21      65.518667  3RRCBE2 - 3RRCBE1
# 22       4.594800  3RRCBE2 - Ed+-2kb
# 23      14.766667   3RRCBE2 - mu-4kb
# 25       0.633733  3RRCBE1 - Ed+-2kb
# 26      39.417222   3RRCBE1 - mu-4kb
# 14      61.978400  3RRCBE2 - 3RRCBE1
# 15       2.689600  3RRCBE2 - Ed+-2kb
# 16      11.685556   3RRCBE2 - mu-4kb
# 18      13.547067  3RRCBE1 - Ed+-2kb
# 19      31.987222   3RRCBE1 - mu-4kb
# 21      50.445067  3RRCBE2 - 3RRCBE1
# 22       5.035600  3RRCBE2 - Ed+-2kb
# 23      16.934889   3RRCBE2 - mu-4kb
# 25       2.288267  3RRCBE1 - Ed+-2kb
# 26      34.071000   3RRCBE1 - mu-4kb
# 0       46.745467  3RRCBE2 - 3RRCBE1
# 1       15.387333  3RRCBE2 - Ed+-2kb
# 2        3.379222   3RRCBE2 - mu-4kb
# 4       24.441200  3RRCBE1 - Ed+-2kb
# 5        8.250222   3RRCBE1 - mu-4kb
# 7       36.904311  3RRCBE2 - 3RRCBE1
# 8        2.572400  3RRCBE2 - Ed+-2kb
# 9        4.676000   3RRCBE2 - mu-4kb
# 11      10.718133  3RRCBE1 - Ed+-2kb
# 12       8.711111   3RRCBE1 - mu-4kb
# 14      49.203200  3RRCBE2 - 3RRCBE1
# 15       0.000000  3RRCBE2 - Ed+-2kb
# 16      16.864000   3RRCBE2 - mu-4kb
# 18       1.506933  3RRCBE1 - Ed+-2kb
# 19      23.127778   3RRCBE1 - mu-4kb
# 35      36.563911  3RRCBE2 - 3RRCBE1
# 36      21.290000  3RRCBE2 - Ed+-2kb
# 37      21.905333   3RRCBE2 - mu-4kb
# 39       3.887200  3RRCBE1 - Ed+-2kb
# 40      77.029444   3RRCBE1 - mu-4kb
# 42      91.924000  3RRCBE2 - 3RRCBE1
# 43       7.126667  3RRCBE2 - Ed+-2kb
# 44       5.953667   3RRCBE2 - mu-4kb
# 46       9.768800  3RRCBE1 - Ed+-2kb
# 47      19.392444   3RRCBE1 - mu-4kb
# 49      29.629200  3RRCBE2 - 3RRCBE1
# 50      10.047467  3RRCBE2 - Ed+-2kb
# 51       9.127667   3RRCBE2 - mu-4kb
# 53      13.644533  3RRCBE1 - Ed+-2kb
# 54      18.509667   3RRCBE1 - mu-4kb
# 28      54.500044  3RRCBE2 - 3RRCBE1
# 29       6.002000  3RRCBE2 - Ed+-2kb
# 30      18.614556   3RRCBE2 - mu-4kb
# 32      10.733600  3RRCBE1 - Ed+-2kb
# 33      11.303222   3RRCBE1 - mu-4kb
# 35      50.449422  3RRCBE2 - 3RRCBE1
# 36       7.311467  3RRCBE2 - Ed+-2kb
# 37      33.093667   3RRCBE2 - mu-4kb
# 39      12.562800  3RRCBE1 - Ed+-2kb
# 40      15.056889   3RRCBE1 - mu-4kb

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5


fig = plt.figure(figsize=(15,10))
maxInteraction = max(contactsums['pinteractions'])
maxInteraction = maxInteraction + maxInteraction/10

markerlist = ['o', 'X', 'o']

ax1 = fig.add_subplot(1, 6, 1)
sns.barplot(data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax1)
markerCounter = 0
for (sampleName, group2) in contactsumsSelf.groupby('sample'):
	sns.stripplot(data=group2, x='regioncomb', y='pinteractions', hue='treatment_time', marker=markerlist[markerCounter], ax=ax1, dodge=True, size=10,
		palette=['black', 'red'])
	markerCounter +=1

boxlist = [] # list with pairs for statistical significance test
for reg in contactsumsSelf['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsumsSelf['treatment_time'].unique()[0]), (reg, contactsumsSelf['treatment_time'].unique()[1]))]
annot = Annotator(ax1, data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', pairs=boxlist)
annot.configure(test='t-test_ind', text_format='simple', verbose=5, comparisons_correction="BH") #
annot.apply_and_annotate()

ax1.legend_.remove()
ax1.set_ylabel('Interactions norm. by N of bins')
ax1.set_xlabel('')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15)



ax = fig.add_subplot(1, 6, (2, 6))
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax, order=region_order)
markerCounter = 0
for (sampleName, group2) in contactsums.groupby('sample'):
	sns.stripplot(data=group2, x='regioncomb', y='pinteractions', hue='treatment_time', marker=markerlist[markerCounter], ax=ax, dodge=True, size=10,
		palette=['black', 'red'], order=region_order)
	markerCounter +=1

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
annot = Annotator(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', pairs=boxlist, order=region_order)
annot.configure(test='t-test_ind', text_format='simple', verbose=5, comparisons_correction="BH") #
annot.apply_and_annotate()

f = lambda m,c: plt.plot([],[],marker=m, color=c, ls="none")[0]
handles, labels = ax.get_legend_handles_labels()
handles += [f(list(set(markerlist))[i], "k") for i in range(len(set(markerlist)))]
labels += ['C9', 'C10']
ax.legend(handles, labels)
ax.set_ylabel('')
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
fig.suptitle(f"5Smu_capture -- x")

fig.savefig('../plots/TriC14/TriC12-14_RamosC9C10_RegOfInterest_markers.pdf')
# Out:
# mu-4kb - mu-4kb_0 vs. mu-4kb - mu-4kb_8: t-test independent samples with Benjamini-Hochberg correction, P_val:1.714e-01 t=1.473e+00
# 3RRCBE2 - mu-4kb_0 vs. 3RRCBE2 - mu-4kb_8: t-test independent samples with Benjamini-Hochberg correction, P_val:2.756e-01 t=-1.153e+00
# 3RRCBE1 - mu-4kb_0 vs. 3RRCBE1 - mu-4kb_8: t-test independent samples with Benjamini-Hochberg correction, P_val:8.382e-01 t=-2.095e-01
# 3RRCBE1 - Ed+-2kb_0 vs. 3RRCBE1 - Ed+-2kb_8: t-test independent samples with Benjamini-Hochberg correction, P_val:7.242e-01 t=3.629e-01
# 3RRCBE2 - 3RRCBE1_0 vs. 3RRCBE2 - 3RRCBE1_8: t-test independent samples with Benjamini-Hochberg correction, P_val:6.999e-01 t=-3.967e-01
# 3RRCBE2 - Ed+-2kb_0 vs. 3RRCBE2 - Ed+-2kb_8: t-test independent samples with Benjamini-Hochberg correction, P_val:4.601e-01 t=-7.682e-01

# %%
plt.rcParams['pdf.fonttype'] = 42
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.size'] = 12
plt.rcParams['lines.linewidth'] = 0.5


fig = plt.figure(figsize=(15,10))
maxInteraction = max(contactsums['pinteractions'])
maxInteraction = maxInteraction + maxInteraction/10

ax1 = fig.add_subplot(1, 6, 1)
sns.barplot(data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax1)
sns.stripplot(data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax1, dodge=True, size=10,
	palette=['black', 'red'])

boxlist = [] # list with pairs for statistical significance test
for reg in contactsumsSelf['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsumsSelf['treatment_time'].unique()[0]), (reg, contactsumsSelf['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax1, data=contactsumsSelf, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, test='t-test_ind', text_format='simple', verbose=2, comparisons_correction=None)

ax1.legend_.remove()
ax1.set_ylabel('Interactions norm. by N of bins')
ax1.set_xlabel('')
ax1.set_xticklabels(ax1.get_xticklabels(), rotation=15)



ax = fig.add_subplot(1, 6, (2, 6))
sns.barplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ci='sd', color='white', linewidth=0.5, edgecolor='black', 
	errcolor='black', errwidth=0.5, capsize=0.1, alpha=0.8, ax=ax, order=region_order)
sns.stripplot(data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', ax=ax, dodge=True, size=10,
	palette=['black', 'red'], order=region_order)

boxlist = [] # list with pairs for statistical significance test
for reg in contactsums['regioncomb'].unique():
	boxlist = boxlist + [((reg, contactsums['treatment_time'].unique()[0]), (reg, contactsums['treatment_time'].unique()[1]))]
statannot.add_stat_annotation(ax, data=contactsums, x='regioncomb', y='pinteractions', hue='treatment_time', box_pairs=boxlist, order=region_order, test='t-test_ind', text_format='simple', verbose=2, comparisons_correction=None)

ax.set_ylabel('')
ax.set_xlabel('')
ax.set_xticklabels(ax.get_xticklabels(), rotation=15)
fig.suptitle(f"5Smu_capture -- x")

fig.savefig('../plots/TriC14/TriC11-12-14_RamosC9C10_RegOfInterest.pdf')
# Out:
# mu-4kb - mu-4kb_0 v.s. mu-4kb - mu-4kb_8: t-test independent samples, P_val=1.714e-01 stat=1.473e+00
# 3RRCBE2 - mu-4kb_0 v.s. 3RRCBE2 - mu-4kb_8: t-test independent samples, P_val=2.756e-01 stat=-1.153e+00
# 3RRCBE1 - mu-4kb_0 v.s. 3RRCBE1 - mu-4kb_8: t-test independent samples, P_val=8.382e-01 stat=-2.095e-01
# 3RRCBE1 - Ed+-2kb_0 v.s. 3RRCBE1 - Ed+-2kb_8: t-test independent samples, P_val=7.242e-01 stat=3.629e-01
# 3RRCBE2 - 3RRCBE1_0 v.s. 3RRCBE2 - 3RRCBE1_8: t-test independent samples, P_val=6.999e-01 stat=-3.967e-01
# 3RRCBE2 - Ed+-2kb_0 v.s. 3RRCBE2 - Ed+-2kb_8: t-test independent samples, P_val=4.601e-01 stat=-7.682e-01
